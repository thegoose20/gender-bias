# %% [markdown]
# # Analysis: Model Output from Experiments

# %% [markdown]
# Load libraries:

# %%
import utils
import pandas as pd
import numpy as np
import re
from pathlib import Path

# %% [markdown]
# ## Description Stereotype and Omission Labels

# %% [markdown]
# Load the dataset of predictions from the final model of a specified experiment (cascade), i.e. a document classifier assigning `Stereotype` and `Omission` labels:

# %%
exp = 3 # 1, 2    # Experiment/cascade number

# %%
output_dir = "../data/token_clf_data/experiment{n}/5fold/output/".format(n=exp)
# f = output_dir+"aggregated_final_predictions_docclf_sgd-svm_so.csv"
f = output_dir+"aggregated_final_pno_predictions_docclf_sgd-svm_so.csv"
df = pd.read_csv(f, index_col=0)
df.head()
# Out:
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description  expected_label    fold  \
# 6   Thomas Young was probably born in 1725. By the...  ['Stereotype']  split4
# 7   Andrew Tait worked on Paramecium in Beale's la...    ['Omission']  split4
# 10    Delivered by Thomson to teachers in Darlington.    ['Omission']  split4
# 14  This was gifted by Thomson to his secretary, M...    ['Omission']  split4
# 22  Catherine Robina Borland was responsible for t...            ['']  split4
#
#                                pers_o_pred  predicted_label
# 6   ['Masculine', 'Occupation', 'Unknown']  ('Stereotype',)
# 7   ['Occupation', 'Masculine', 'Unknown']    ('Omission',)
# 10               ['Occupation', 'Unknown']    ('Omission',)
# 14   ['Occupation', 'Feminine', 'Unknown']    ('Omission',)
# 22                          ['Occupation']            ('',)

# %% [markdown]
# ***
# Investigate the classification of the three example descriptions used for the *Metadata Bias Workshop* (April 20, 2023) with the HC team, comparing the manual (expected) labels to the model-made (predicted) labels:

# %%
# df_ling = pd.read_csv(output_dir+"cc-rf_linglabels_baseline_fastText100_predictions.csv", index_col=0)
df_perso = pd.read_csv(output_dir+"crf_arow_pers_o_baseline_fastText100_predictions.csv", index_col=0)

# %%
descs = list(df.description)
desc_ids = list(df.description_id)
for d in descs:
    if "housekeeping tips and matters of general interest to Florence Jewel Baillie" in d:
        print(desc_ids[descs.index(d)], d)
    if "his wife at the coronation of Elizabeth II" in d:
        print(desc_ids[descs.index(d)], d)
    if "Broadcast of the service comemorating" in d:
        print(desc_ids[descs.index(d)], d)
# Out:
# 376 Broadcast of the service comemorating the centenary of the death of Henry Duncan, at which John Baillie was preacher. He gave a biographical talk on Duncan's life and work.
# 407 Correspondence and related items, relating to the attendence of John Baillie and his wife at the coronation of Elizabeth II.
# 444 Mixture of press cuttings covering many subjects including articles on Deitrich Bonhoeffer and Reinhold Niebuhr, Second World War, housekeeping tips and matters of general interest to Florence Jewel Baillie.

# %%
df.loc[df.description_id == 444]
# Out:
#        description_id  start_offset  end_offset               field  \
# 11539             444          4937        5165  Scope and Contents
#
#                                              description  expected_label  \
# 11539  Mixture of press cuttings covering many subjec...  ['Stereotype']
#
#          fold  pers_o_pred predicted_label
# 11539  split3  ['Unknown']           ('',)

# %%
# df_ling.loc[df_ling.description_id == 444]

# %%
df_perso.loc[df_perso.description_id == 444]
# Out:
#       sentence_id    fold  token_id  description_id      sentence  \
# 1201          496  split0      5865             444         Scope
# 1202          496  split0      5866             444           and
# 1203          496  split0      5867             444      Contents
# 1204          496  split0      5868             444             :
# 1205          496  split0      5869             444       Mixture
# 1206          496  split0      5870             444            of
# 1207          496  split0      5871             444         press
# 1208          496  split0      5872             444      cuttings
# 1209          496  split0      5873             444      covering
# 1210          496  split0      5874             444          many
# 1211          496  split0      5875             444      subjects
# 1212          496  split0      5876             444     including
# 1213          496  split0      5877             444      articles
# 1214          496  split0      5878             444            on
# 1215          496  split0      5879             444      Deitrich
# 1216          496  split0      5880             444    Bonhoeffer
# 1217          496  split0      5881             444           and
# 1218          496  split0      5882             444      Reinhold
# 1219          496  split0      5883             444       Niebuhr
# 1220          496  split0      5884             444             ,
# 1221          496  split0      5885             444        Second
# 1222          496  split0      5886             444         World
# 1223          496  split0      5887             444           War
# 1224          496  split0      5888             444             ,
# 1225          496  split0      5889             444  housekeeping
# 1226          496  split0      5890             444          tips
# 1227          496  split0      5891             444           and
# 1228          496  split0      5892             444       matters
# 1229          496  split0      5893             444            of
# 1230          496  split0      5894             444       general
# 1231          496  split0      5895             444      interest
# 1232          496  split0      5896             444            to
# 1233          496  split0      5897             444      Florence
# 1234          496  split0      5898             444         Jewel
# 1235          496  split0      5899             444       Baillie
# 1236          496  split0      5900             444             .
#
#      tag_pers_o_expected tag_pers_o_predicted
# 1201                   O                    O
# 1202                   O                    O
# 1203                   O                    O
# 1204                   O                    O
# 1205                   O                    O
# 1206                   O                    O
# 1207                   O                    O
# 1208                   O                    O
# 1209                   O                    O
# 1210                   O                    O
# 1211                   O                    O
# 1212                   O                    O
# 1213                   O                    O
# 1214                   O                    O
# 1215           B-Unknown                    O
# 1216           I-Unknown                    O
# 1217                   O                    O
# 1218           B-Unknown            B-Unknown
# 1219           I-Unknown            I-Unknown
# 1220           I-Unknown            I-Unknown
# 1221                   O            I-Unknown
# 1222                   O                    O
# 1223                   O                    O
# 1224                   O                    O
# 1225                   O                    O
# 1226                   O                    O
# 1227                   O                    O
# 1228                   O                    O
# 1229                   O                    O
# 1230                   O                    O
# 1231                   O                    O
# 1232                   O                    O
# 1233           B-Unknown            B-Unknown
# 1234           I-Unknown            I-Unknown
# 1235           I-Unknown            I-Unknown
# 1236           I-Unknown            I-Unknown

# %%
df.loc[df.description_id == 407]
# Out:
#        description_id  start_offset  end_offset               field  \
# 25245             407          4339        4484  Scope and Contents
#
#                                              description  \
# 25245  Correspondence and related items, relating to ...
#
#                    expected_label    fold  pers_o_pred predicted_label
# 25245  ['Omission', 'Stereotype']  split4  ['Unknown']           ('',)

# %%
# df_ling.loc[df_ling.description_id == 407]

# %%
df_perso.loc[df_perso.description_id == 407]
# Out:
#         sentence_id    fold  token_id  description_id        sentence  \
# 149957          453  split1      4751             407           Scope
# 149958          453  split1      4752             407             and
# 149959          453  split1      4753             407        Contents
# 149960          453  split1      4754             407               :
# 149961          453  split1      4755             407  Correspondence
# 149962          453  split1      4756             407             and
# 149963          453  split1      4757             407         related
# 149964          453  split1      4758             407           items
# 149965          453  split1      4759             407               ,
# 149966          453  split1      4760             407        relating
# 149967          453  split1      4761             407              to
# 149968          453  split1      4762             407             the
# 149969          453  split1      4763             407      attendence
# 149970          453  split1      4764             407              of
# 149971          453  split1      4765             407            John
# 149972          453  split1      4766             407         Baillie
# 149973          453  split1      4767             407             and
# 149974          453  split1      4768             407             his
# 149975          453  split1      4769             407            wife
# 149976          453  split1      4770             407              at
# 149977          453  split1      4771             407             the
# 149978          453  split1      4772             407      coronation
# 149979          453  split1      4773             407              of
# 149980          453  split1      4774             407       Elizabeth
# 149981          453  split1      4775             407              II
# 149982          453  split1      4776             407               .
#
#        tag_pers_o_expected tag_pers_o_predicted
# 149957                   O                    O
# 149958                   O                    O
# 149959                   O                    O
# 149960                   O                    O
# 149961                   O                    O
# 149962                   O                    O
# 149963                   O                    O
# 149964                   O                    O
# 149965                   O                    O
# 149966                   O                    O
# 149967                   O                    O
# 149968                   O                    O
# 149969                   O                    O
# 149970                   O                    O
# 149971         B-Masculine            B-Unknown
# 149972         I-Masculine            I-Unknown
# 149973                   O                    O
# 149974                   O                    O
# 149975                   O                    O
# 149976                   O                    O
# 149977                   O                    O
# 149978                   O                    O
# 149979                   O                    O
# 149980           B-Unknown                    O
# 149981           I-Unknown                    O
# 149982           I-Unknown                    O

# %%
df.loc[df.description_id == 376]
# Out:
#        description_id  start_offset  end_offset               field  \
# 20691             376          2166        2359  Scope and Contents
#
#                                              description expected_label  \
# 20691  Broadcast of the service comemorating the cent...           ['']
#
#          fold               pers_o_pred predicted_label
# 20691  split4  ['Masculine', 'Unknown']           ('',)

# %%
# df_ling.loc[df_ling.description_id == 376]

# %%
df_perso.loc[df_perso.description_id == 376]
# Out:
#         sentence_id    fold  token_id  description_id      sentence  \
# 452826          415  split3      3739             376         Scope
# 452827          415  split3      3740             376           and
# 452828          415  split3      3741             376      Contents
# 452829          415  split3      3742             376             :
# 452830          415  split3      3743             376     Broadcast
# 452831          415  split3      3744             376            of
# 452832          415  split3      3745             376           the
# 452833          415  split3      3746             376       service
# 452834          415  split3      3747             376  comemorating
# 452835          415  split3      3748             376           the
# 452836          415  split3      3749             376     centenary
# 452837          415  split3      3750             376            of
# 452838          415  split3      3751             376           the
# 452839          415  split3      3752             376         death
# 452840          415  split3      3753             376            of
# 452841          415  split3      3754             376         Henry
# 452842          415  split3      3755             376        Duncan
# 452843          415  split3      3756             376             ,
# 452844          415  split3      3757             376            at
# 452845          415  split3      3758             376         which
# 452846          415  split3      3759             376          John
# 452847          415  split3      3760             376       Baillie
# 452848          415  split3      3761             376           was
# 452849          415  split3      3762             376      preacher
# 452850          415  split3      3763             376             .
# 605285          416  split4      3764             376            He
# 605286          416  split4      3765             376          gave
# 605287          416  split4      3766             376             a
# 605288          416  split4      3767             376  biographical
# 605289          416  split4      3768             376          talk
# 605290          416  split4      3769             376            on
# 605291          416  split4      3770             376        Duncan
# 605292          416  split4      3771             376            's
# 605293          416  split4      3772             376          life
# 605294          416  split4      3773             376           and
# 605295          416  split4      3774             376          work
# 605296          416  split4      3775             376             .
#
#        tag_pers_o_expected tag_pers_o_predicted
# 452826                   O                    O
# 452827                   O                    O
# 452828                   O                    O
# 452829                   O                    O
# 452830                   O                    O
# 452831                   O                    O
# 452832                   O                    O
# 452833                   O                    O
# 452834                   O                    O
# 452835                   O                    O
# 452836                   O                    O
# 452837                   O                    O
# 452838                   O                    O
# 452839                   O                    O
# 452840                   O                    O
# 452841           B-Unknown            B-Unknown
# 452842           I-Unknown            I-Unknown
# 452843           I-Unknown            I-Unknown
# 452844                   O                    O
# 452845                   O                    O
# 452846           B-Unknown          B-Masculine
# 452847           I-Unknown          I-Masculine
# 452848                   O                    O
# 452849        B-Occupation                    O
# 452850        I-Occupation                    O
# 605285                   O                    O
# 605286                   O                    O
# 605287                   O                    O
# 605288                   O                    O
# 605289                   O                    O
# 605290                   O                    O
# 605291           B-Unknown            B-Unknown
# 605292           I-Unknown            I-Unknown
# 605293                   O                    O
# 605294                   O                    O
# 605295                   O                    O
# 605296                   O                    O

# %% [markdown]
# ***

# %%
if exp == 3:
    pred_col = "predicted_label" 
    exp_col = "expected_label" 
    df = utils.getColumnValuesAsLists(df, pred_col)
    df = utils.getColumnValuesAsLists(df, exp_col)
    df = utils.getColumnValuesAsLists(df, "pers_o_pred")
elif exp == 2:
    pred_col = "sgd-svm_label"
    exp_col = "manual_label"
    df = utils.getColumnValuesAsLists(df, pred_col)
    df = utils.getColumnValuesAsLists(df, exp_col)
    df = utils.getColumnValuesAsLists(df, "doc_ling_pred")
else:
    pred_col = "sgd-svm_label"
    exp_col = "manual_label"
    df = utils.getColumnValuesAsLists(df, pred_col)
    df = utils.getColumnValuesAsLists(df, exp_col)
    df = utils.getColumnValuesAsLists(df, "doc_ling_pred")
    df = utils.getColumnValuesAsLists(df, "doc_pers_o_pred")

# %%
preds = list(df[pred_col])
preds[:5]
# Out:
# [['Stereotype'], ['Omission'], ['Omission'], ['Omission'], ['']]

# %%
pred_df = df[["description_id", "start_offset", "end_offset", "field", "description", pred_col]]
pred_df = pred_df.explode([pred_col])
pred_df[pred_col] = pred_df[pred_col].replace(to_replace="", value="None")
pred_df.head()
# Out:
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description sgd-svm_label
# 6   Thomas Young was probably born in 1725. By the...    Stereotype
# 7   Andrew Tait worked on Paramecium in Beale's la...      Omission
# 10    Delivered by Thomson to teachers in Darlington.      Omission
# 14  This was gifted by Thomson to his secretary, M...      Omission
# 22  Catherine Robina Borland was responsible for t...          None

# %% [markdown]
# Join the EADID (fonds, or collection, identifier) to the data:

# %%
ann_df = pd.read_csv("../data/crc_metadata/annot_descs.csv", usecols=["description_id", "file"])
eadid_col = list(ann_df["file"])
ann_df = ann_df.drop(columns=["file"])
eadid_col = [filename.split("_")[0] for filename in eadid_col]
ann_df.insert(1, "eadid", eadid_col)
ann_df.head()
# Out:
#    description_id eadid
# 0               0   AA5
# 1               1   AA5
# 2               2   AA5
# 3               3   AA5
# 4               4   AA6

# %%
print(pred_df.shape)
pred_df = pred_df.join(ann_df.set_index("description_id"), on="description_id")
print(pred_df.shape)
pred_df.head()
# Out:
# (28319, 6)
# (28319, 7)
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description sgd-svm_label      eadid
# 6   Thomas Young was probably born in 1725. By the...    Stereotype  Coll-1253
# 7   Andrew Tait worked on Paramecium in Beale's la...      Omission  Coll-1255
# 10    Delivered by Thomson to teachers in Darlington.      Omission  Coll-1310
# 14  This was gifted by Thomson to his secretary, M...      Omission  Coll-1310
# 22  Catherine Robina Borland was responsible for t...          None  Coll-1453

# %% [markdown]
# Save the data as JSON:

# %%
# Remove offset columns and create an index without duplicate values
pred_df = pred_df[["eadid", "description_id", "field", "description", pred_col]].reset_index().drop(columns=["index"])
pred_df = pred_df.rename(columns={pred_col:"prediction"})
pred_df.head()
# Out:
#        eadid  description_id                      field  \
# 0  Coll-1253            3027  Biographical / Historical
# 1  Coll-1255            3397  Biographical / Historical
# 2  Coll-1310            4736  Biographical / Historical
# 3  Coll-1310            4712  Biographical / Historical
# 4  Coll-1453           15684  Biographical / Historical
#
#                                          description  prediction
# 0  Thomas Young was probably born in 1725. By the...  Stereotype
# 1  Andrew Tait worked on Paramecium in Beale's la...    Omission
# 2    Delivered by Thomson to teachers in Darlington.    Omission
# 3  This was gifted by Thomson to his secretary, M...    Omission
# 4  Catherine Robina Borland was responsible for t...        None

# %%
json_data = pred_df.to_json(orient="records")
json_data[0:500]
# Out:
# '[{"eadid":"Coll-1253","description_id":3027,"field":"Biographical \\/ Historical","description":"Thomas Young was probably born in 1725. By the summer of 1751, Young was practicing surgery in Edinburgh. In 1756 he was appointed Professor of Midwifery at Edinburgh University - only the third holder of that Chair, after Robert Smith and Joseph Gibson, the first holder. Young was the first Professor of Midwifery at Edinburgh to actually lecture on the subject of obstetrics. He also had an associatio'

# %%
with open(output_dir+"so_doc_clf_preds.json", "w") as f:
    f.write(json_data)
    f.close
print("File written!")
# Out:
# File written!

# %% [markdown]
# Sum the labels across documents (descriptions):

# %%
pred_col = "prediction"
label_df = pd.DataFrame(pred_df[pred_col].value_counts())
label_df = label_df.rename(columns={pred_col:"Total Descriptions"})
label_df = label_df.T
label_df
# Out:
#                      None  Omission  Stereotype
# Total Descriptions  24388      2578        1321

# %%
def getLabelCountsPerField(df, pred_col, field):
    if field == None:
        label_df = pd.DataFrame(df[pred_col].value_counts())
        label_df = label_df.rename(columns={pred_col:"Total Descriptions"})
    else:
        subdf = df.loc[df["field"] == field]
        label_df = pd.DataFrame(subdf[pred_col].value_counts())
        label_df = label_df.rename(columns={pred_col:field})
    label_df = label_df.T
    return label_df

# %%
label_df = getLabelCountsPerField(pred_df, pred_col, None)
fields = pred_df.field.unique()
for field in fields:
    label_df = pd.concat([label_df, getLabelCountsPerField(pred_df, pred_col, field)])
label_df = label_df.reset_index()
label_df = label_df.rename(columns={"index":"Field"})
label_df = label_df.fillna(0)
label_df
# Out:
#                        Field   None  Omission  Stereotype
# 0         Total Descriptions  24388    2578.0      1321.0
# 1  Biographical / Historical    311     317.0       162.0
# 2                      Title  14062     689.0       347.0
# 3         Scope and Contents   9712    1572.0       812.0
# 4     Processing Information    303       0.0         0.0

# %% [markdown]
# Calculate the proportions:

# %%
df_percentages = []
for row in range(label_df.shape[0]):
    row_percentages = []
    for col in range(1,len(label_df.columns)):
        row_percentages += [label_df.iloc[row,col]/label_df.iloc[row,1:].sum()]
    df_percentages += [row_percentages]
# df_percentages

# %%
label_df2 = pd.concat([label_df["Field"], pd.DataFrame(df_percentages).reset_index()], axis=1)
label_df2 = label_df2.drop(columns=["index"])
label_df2 = label_df2.rename(columns={0:"None", 1:"Omission", 2:"Stereotype"})
label_df2 = label_df2.fillna(0)
label_df2
# Out:
#                        Field      None  Omission  Stereotype
# 0         Total Descriptions  0.862163  0.091137    0.046700
# 1  Biographical / Historical  0.393671  0.401266    0.205063
# 2                      Title  0.931382  0.045635    0.022983
# 3         Scope and Contents  0.802910  0.129960    0.067130
# 4     Processing Information  1.000000  0.000000    0.000000

# %%
label_df.insert(1, "Metric", (["Count"]*label_df.shape[0]))
label_df2.insert(1, "Metric", (["Proportion"]*label_df2.shape[0]))
label_df = pd.concat([label_df, label_df2])
label_df = label_df.fillna(0)
label_df
# Out:
#                        Field      Metric          None     Omission  \
# 0         Total Descriptions       Count  24388.000000  2578.000000
# 1  Biographical / Historical       Count    311.000000   317.000000
# 2                      Title       Count  14062.000000   689.000000
# 3         Scope and Contents       Count   9712.000000  1572.000000
# 4     Processing Information       Count    303.000000     0.000000
# 0         Total Descriptions  Proportion      0.862163     0.091137
# 1  Biographical / Historical  Proportion      0.393671     0.401266
# 2                      Title  Proportion      0.931382     0.045635
# 3         Scope and Contents  Proportion      0.802910     0.129960
# 4     Processing Information  Proportion      1.000000     0.000000
#
#     Stereotype
# 0  1321.000000
# 1   162.000000
# 2   347.000000
# 3   812.000000
# 4     0.000000
# 0     0.046700
# 1     0.205063
# 2     0.022983
# 3     0.067130
# 4     0.000000

# %%
label_df = label_df.groupby(by="Field", group_keys=True).apply(lambda x: x).drop(columns=["Field"])
label_df
# Out:
#                                  Metric          None     Omission  \
# Field
# Biographical / Historical 1       Count    311.000000   317.000000
#                           1  Proportion      0.393671     0.401266
# Processing Information    4       Count    303.000000     0.000000
#                           4  Proportion      1.000000     0.000000
# Scope and Contents        3       Count   9712.000000  1572.000000
#                           3  Proportion      0.802910     0.129960
# Title                     2       Count  14062.000000   689.000000
#                           2  Proportion      0.931382     0.045635
# Total Descriptions        0       Count  24388.000000  2578.000000
#                           0  Proportion      0.862163     0.091137
#
#                               Stereotype
# Field
# Biographical / Historical 1   162.000000
#                           1     0.205063
# Processing Information    4     0.000000
#                           4     0.000000
# Scope and Contents        3   812.000000
#                           3     0.067130
# Title                     2   347.000000
#                           2     0.022983
# Total Descriptions        0  1321.000000
#                           0     0.046700

# %% [markdown]
# Save the data:

# %%
analysis_dir = "../data/token_clf_data/experiment{n}/5fold/analysis/".format(n=exp)
Path(analysis_dir).mkdir(parents=True, exist_ok=True)  # For predictions
label_df.to_csv(analysis_dir+"doc_counts_proportions_pred_label.csv")

# %% [markdown]
# Update the document classifier output data with the EADID column:

# %%
ann_df = pd.read_csv("../data/crc_metadata/annot_descs.csv", usecols=["description_id", "file"])
eadid_col = list(ann_df["file"])
ann_df = ann_df.drop(columns=["file"])
eadid_col = [filename.split("_")[0] for filename in eadid_col]
ann_df.insert(1, "eadid", eadid_col)
df = df.join(ann_df.set_index("description_id"), on="description_id")
df.head()
# Out:
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description expected_label    fold  \
# 6   Thomas Young was probably born in 1725. By the...   [Stereotype]  split4
# 7   Andrew Tait worked on Paramecium in Beale's la...     [Omission]  split4
# 10    Delivered by Thomson to teachers in Darlington.     [Omission]  split4
# 14  This was gifted by Thomson to his secretary, M...     [Omission]  split4
# 22  Catherine Robina Borland was responsible for t...             []  split4
#
#                          pers_o_pred predicted_label      eadid
# 6   [Occupation, Unknown, Masculine]    [Stereotype]  Coll-1253
# 7   [Unknown, Occupation, Masculine]      [Omission]  Coll-1255
# 10             [Unknown, Occupation]      [Omission]  Coll-1310
# 14   [Unknown, Occupation, Feminine]      [Omission]  Coll-1310
# 22                      [Occupation]              []  Coll-1453

# %%
f = output_dir+"aggregated_final_predictions_docclf_sgd-svm_so.csv"
df.to_csv(f)

# %% [markdown]
# ### Join Labeled Descriptions to Additional Catalog Metadata

# %% [markdown]
# Examine specific labels more closely, looking at **experiment 2's classification of descriptions with Omission** (as this model cascade performed best on that label) and **experiment 3's classification of descriptions with Stereotype** (as this model cascade performed best on that label):

# %%
label = "Stereotype" #"Omission"
pred_col = "predicted_label" #"sgd-svm_label"

# %%
df_exploded = df.explode([pred_col])
df_exploded.head()
# Out:
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description expected_label    fold  \
# 6   Thomas Young was probably born in 1725. By the...   [Stereotype]  split4
# 7   Andrew Tait worked on Paramecium in Beale's la...     [Omission]  split4
# 10    Delivered by Thomson to teachers in Darlington.     [Omission]  split4
# 14  This was gifted by Thomson to his secretary, M...     [Omission]  split4
# 22  Catherine Robina Borland was responsible for t...             []  split4
#
#                          pers_o_pred predicted_label      eadid
# 6   [Occupation, Unknown, Masculine]      Stereotype  Coll-1253
# 7   [Unknown, Occupation, Masculine]        Omission  Coll-1255
# 10             [Unknown, Occupation]        Omission  Coll-1310
# 14   [Unknown, Occupation, Feminine]        Omission  Coll-1310
# 22                      [Occupation]                  Coll-1453

# %%
subdf = df_exploded.loc[df_exploded[pred_col] == label] # Only predictions of specified label
print(subdf.shape)
subdf.head()
# Out:
# (1321, 10)
#      description_id  start_offset  end_offset                      field  \
# 6              3027           627        1162  Biographical / Historical
# 58             2135           490        1643  Biographical / Historical
# 71             5533          3379        6106  Biographical / Historical
# 84             1174          2183        4687  Biographical / Historical
# 105           27353           468        1233  Biographical / Historical
#
#                                            description  \
# 6    Thomas Young was probably born in 1725. By the...
# 58   Edward Adrian Wilson (Wilson of the Antarctic)...
# 71   Gerald Henry Elliot was born in Edinburgh on 2...
# 84   Eric Olof Lundholm was born in 1915 in Modderf...
# 105  Novelist Samuel Rutherford Crockett was born i...
#
#              expected_label    fold  \
# 6              [Stereotype]  split4
# 58                       []  split4
# 71   [Omission, Stereotype]  split4
# 84   [Omission, Stereotype]  split4
# 105                      []  split4
#
#                                     pers_o_pred predicted_label      eadid
# 6              [Occupation, Unknown, Masculine]      Stereotype  Coll-1253
# 58   [Unknown, Feminine, Occupation, Masculine]      Stereotype  Coll-1087
# 71   [Unknown, Feminine, Occupation, Masculine]      Stereotype  Coll-1357
# 84             [Unknown, Occupation, Masculine]      Stereotype  Coll-1055
# 105            [Unknown, Occupation, Masculine]      Stereotype  Coll-1475

# %%
df_eadid_counts = pd.DataFrame(subdf.eadid.value_counts()).reset_index()
df_eadid_counts = df_eadid_counts.rename(columns={"index":"eadid","eadid":"desc_count"})
df_eadid_counts = df_eadid_counts.sort_values(by=["desc_count"], ascending=False)
df_eadid_counts.head()
# Out:
#        eadid  desc_count
# 0  Coll-1434         820
# 1   Coll-146         301
# 2        BAI          23
# 3  Coll-1057           9
# 4  Coll-1362           4

# %% [markdown]
# Join the other metadata from the catalog to the eadid (fonds, or collection) data:

# %%
meta_df = pd.read_csv("../data/crc_metadata/CRC_units-grouped-by-fonds_clean.csv", index_col=0)
df_joined = df_eadid_counts.join(meta_df.set_index("eadid"), on=["eadid"], how="outer")
df_joined = df_joined.rename(columns={"desc_count":"{label}_exp{n}_desc_count".format(label=label.lower(), n=exp)})
df_joined.head()
# Out:
#          eadid  stereotype_exp3_desc_count  omission_exp2_desc_count  \
# 0.0  Coll-1434                       820.0                     916.0
# 1.0   Coll-146                       301.0                     161.0
# 2.0        BAI                        23.0                      13.0
# 3.0  Coll-1057                         9.0                      32.0
# 4.0  Coll-1362                         4.0                       2.0
#
#                                             unit_title  \
# 0.0  ['Roslin Slide Collection', 'Stack of Medical ...
# 1.0                                                NaN
# 2.0  ['Papers of Professor John Baillie, and Bailli...
# 3.0  ['Papers of Alan W. Greenwood', 'Academic cert...
# 4.0  ['Roslin Institute Offprint Collection', 'Anim...
#
#                                        unit_identifier  \
# 0.0  ['Coll-1434', 'Coll-1434/1', 'Coll-1434/2', 'C...
# 1.0                                                NaN
# 2.0  ['BAI', 'BAI 1', 'BAI 1/1', 'BAI 1/1/1', 'BAI ...
# 3.0  ['Coll-1057', 'Coll-1057/1', 'Coll-1057/1/1', ...
# 4.0  ['Coll-1362', 'Coll-1362/1', 'Coll-1362/1/1', ...
#
#                               unique_language  \
# 0.0                               ['English']
# 1.0                                       NaN
# 2.0  ['English', 'Greek', 'Hebrew', 'German']
# 3.0          ['English', 'Russian', 'French']
# 4.0                               ['English']
#
#                                            unique_date  \
# 0.0  ['1870-01-01 - 1930-12-31', '1870-01-01 - 1930...
# 1.0                                                NaN
# 2.0  ['1880-01-01 - 2003-12-31', '1900-01-01 - 1964...
# 3.0  ['1889-01-01 - 1943-12-31', '1916-01-01 - 1931...
# 4.0  ['1947-01-01 - 2007-12-31', '1947-01-01 - 1985...
#
#                                       unique_geography
# 0.0  ['Winnipeg (Manitoba', 'Tulliallan (Scotland)'...
# 1.0                                                NaN
# 2.0  ['Argentina', 'Dunedin (New Zealand)', 'New Ze...
# 3.0  ['Edinburgh (Scotland)', 'Wye Mills Talbot Cou...
# 4.0  ['New Zealand', 'Mexico', 'Great Britain', 'Sc...

# %% [markdown]
# Note any missing data:

# %%
df_joined.loc[df_joined.unit_title.isna()]
# Out:
#            eadid  stereotype_exp3_desc_count  omission_exp2_desc_count  \
# 1.0     Coll-146                       301.0                     161.0
# 118.0        AA5                         1.0                       NaN
# 97.0   Coll-1320                         1.0                       3.0
# 156.0  Coll-1176                         1.0                       2.0
# 132.0  Coll-1492                         1.0                       2.0
# 80.0   Coll-1307                         1.0                       NaN
# 85.0         AA7                         1.0                       1.0
# 15.0   Coll-1022                         1.0                       4.0
# 70.0         AA6                         1.0                       NaN
# NaN    Coll-1266                         NaN                      19.0
# NaN      Coll-13                         NaN                       1.0
#
#       unit_title unit_identifier unique_language unique_date unique_geography
# 1.0          NaN             NaN             NaN         NaN              NaN
# 118.0        NaN             NaN             NaN         NaN              NaN
# 97.0         NaN             NaN             NaN         NaN              NaN
# 156.0        NaN             NaN             NaN         NaN              NaN
# 132.0        NaN             NaN             NaN         NaN              NaN
# 80.0         NaN             NaN             NaN         NaN              NaN
# 85.0         NaN             NaN             NaN         NaN              NaN
# 15.0         NaN             NaN             NaN         NaN              NaN
# 70.0         NaN             NaN             NaN         NaN              NaN
# NaN          NaN             NaN             NaN         NaN              NaN
# NaN          NaN             NaN             NaN         NaN              NaN

# %% [markdown]
# Save the metadata with this additional column:

# %%
df_joined.to_csv("../data/crc_metadata/CRC_units-grouped-by-fonds_clean.csv")

# %% [markdown]
# Analyze the results:

# %%
unique_fonds = list(df_joined.eadid.unique())
print(len(unique_fonds))
# Out:
# 848

# %%
# Top Stereotype collections
top_st = df_joined.sort_values(by=["stereotype_exp3_desc_count"], ascending=False).head(50)
top_st.head()
# Out:
#          eadid  stereotype_exp3_desc_count  omission_exp2_desc_count  \
# 0.0  Coll-1434                       820.0                     916.0
# 1.0   Coll-146                       301.0                     161.0
# 2.0        BAI                        23.0                      13.0
# 3.0  Coll-1057                         9.0                      32.0
# 4.0  Coll-1362                         4.0                       2.0
#
#                                             unit_title  \
# 0.0  ['Roslin Slide Collection', 'Stack of Medical ...
# 1.0                                                NaN
# 2.0  ['Papers of Professor John Baillie, and Bailli...
# 3.0  ['Papers of Alan W. Greenwood', 'Academic cert...
# 4.0  ['Roslin Institute Offprint Collection', 'Anim...
#
#                                        unit_identifier  \
# 0.0  ['Coll-1434', 'Coll-1434/1', 'Coll-1434/2', 'C...
# 1.0                                                NaN
# 2.0  ['BAI', 'BAI 1', 'BAI 1/1', 'BAI 1/1/1', 'BAI ...
# 3.0  ['Coll-1057', 'Coll-1057/1', 'Coll-1057/1/1', ...
# 4.0  ['Coll-1362', 'Coll-1362/1', 'Coll-1362/1/1', ...
#
#                               unique_language  \
# 0.0                               ['English']
# 1.0                                       NaN
# 2.0  ['English', 'Greek', 'Hebrew', 'German']
# 3.0          ['English', 'Russian', 'French']
# 4.0                               ['English']
#
#                                            unique_date  \
# 0.0  ['1870-01-01 - 1930-12-31', '1870-01-01 - 1930...
# 1.0                                                NaN
# 2.0  ['1880-01-01 - 2003-12-31', '1900-01-01 - 1964...
# 3.0  ['1889-01-01 - 1943-12-31', '1916-01-01 - 1931...
# 4.0  ['1947-01-01 - 2007-12-31', '1947-01-01 - 1985...
#
#                                       unique_geography
# 0.0  ['Winnipeg (Manitoba', 'Tulliallan (Scotland)'...
# 1.0                                                NaN
# 2.0  ['Argentina', 'Dunedin (New Zealand)', 'New Ze...
# 3.0  ['Edinburgh (Scotland)', 'Wye Mills Talbot Cou...
# 4.0  ['New Zealand', 'Mexico', 'Great Britain', 'Sc...

# %%
# Top Omission collections
top_om = df_joined.sort_values(by=["omission_exp2_desc_count"], ascending=False).head(50)
top_om.head()
# Out:
#            eadid  stereotype_exp3_desc_count  omission_exp2_desc_count  \
# 0.0    Coll-1434                       820.0                     916.0
# 9.0    Coll-1310                         2.0                     623.0
# 115.0  Coll-1064                         1.0                     239.0
# 1.0     Coll-146                       301.0                     161.0
# NaN    Coll-1255                         NaN                     143.0
#
#                                               unit_title  \
# 0.0    ['Roslin Slide Collection', 'Stack of Medical ...
# 9.0    ['Papers of Godfrey H. Thomson', 'Biographical...
# 115.0  ['Papers of Professor Walter Ledermann', '1 (3...
# 1.0                                                  NaN
# NaN    ['Papers of Geoffrey Beale, founder of malaria...
#
#                                          unit_identifier  \
# 0.0    ['Coll-1434', 'Coll-1434/1', 'Coll-1434/2', 'C...
# 9.0    ['Coll-1310', 'Coll-1310-1', 'Coll-1310/1/1', ...
# 115.0  ['Coll-1064', 'Coll-1064/1', 'Coll-1064/2', 'C...
# 1.0                                                  NaN
# NaN    ['Coll-1255', 'Coll-1255/1', 'Coll-1255/2', 'C...
#
#                                          unique_language  \
# 0.0                                          ['English']
# 9.0    ['French', 'English', 'German', 'Swedish', 'Po...
# 115.0                                        ['English']
# 1.0                                                  NaN
# NaN    ['English', 'Russian', 'German', 'Italian', 'F...
#
#                                              unique_date  \
# 0.0    ['1870-01-01 - 1930-12-31', '1870-01-01 - 1930...
# 9.0    ['1890-01-01 - 1978-12-31', '1890-01-01 - 1978...
# 115.0  ['1937-01-01 - 1954-12-31', '1937-02-02 - 1938...
# 1.0                                                  NaN
# NaN    ['1876-01-01 - 2003-12-31', '1947-01-01 - 2002...
#
#                                         unique_geography
# 0.0    ['Winnipeg (Manitoba', 'Tulliallan (Scotland)'...
# 9.0    ['St Andrews (Scotland)', 'Falkirk Scotland', ...
# 115.0  ['Edinburgh (Scotland)', 'St Andrews (Scotland...
# 1.0                                                  NaN
# NaN                                                 ['']

# %% [markdown]
# Save the top 50 rows for each label's description count:

# %%
top_st.to_csv("../data/crc_metadata/top50_stereotype_desc_count.csv")
top_om.to_csv("../data/crc_metadata/top50_omission_desc_count.csv")

# %% [markdown]
# Get and export the descriptions only from the **top 3** Omission- and Stereotype-labeled fonds:

# %%
exp = 3

# %%
output_dir = "../data/token_clf_data/experiment{n}/5fold/output/".format(n=exp)
f = output_dir+"aggregated_final_predictions_docclf_sgd-svm_so.csv"                     # From 5-fold cross validation
df = pd.read_csv(f, index_col=0)
df.head()
# Out:
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description  expected_label    fold  \
# 6   Thomas Young was probably born in 1725. By the...  ['Stereotype']  split4
# 7   Andrew Tait worked on Paramecium in Beale's la...    ['Omission']  split4
# 10    Delivered by Thomson to teachers in Darlington.    ['Omission']  split4
# 14  This was gifted by Thomson to his secretary, M...    ['Omission']  split4
# 22  Catherine Robina Borland was responsible for t...            ['']  split4
#
#                                pers_o_pred predicted_label      eadid
# 6   ['Occupation', 'Unknown', 'Masculine']  ['Stereotype']  Coll-1253
# 7   ['Unknown', 'Occupation', 'Masculine']    ['Omission']  Coll-1255
# 10               ['Unknown', 'Occupation']    ['Omission']  Coll-1310
# 14   ['Unknown', 'Occupation', 'Feminine']    ['Omission']  Coll-1310
# 22                          ['Occupation']            ['']  Coll-1453

# %%
top_st = pd.read_csv("../data/crc_metadata/top50_stereotype_desc_count.csv", index_col=0)
top_st = top_st.sort_values(by="stereotype_exp3_desc_count", ascending=False)
top_st_eadids = list(top_st.eadid)[:3]
df = df.loc[df.eadid.isin(top_st_eadids)]
# Only keep the rows with a label
df = utils.getColumnValuesAsLists(df, "predicted_label")
df_exploded = df.explode(["predicted_label"])
subdf = df_exploded.loc[df_exploded["predicted_label"] == "Stereotype"]
print(subdf.shape)
subdf.head()
# Out:
# (1144, 10)
#      description_id  start_offset  end_offset                      field  \
# 128             720           136        3561  Biographical / Historical
# 382             733          6804        7584  Biographical / Historical
# 466           21619          1346        1430                      Title
# 534           21359          1840        1887                      Title
# 567           22001          1788        1820                      Title
#
#                                            description  \
# 128  John Baillie was born in 1886, the son of Rev ...
# 382  In the couse of his life, John Baillie acquire...
# 466  Close-up photograph of Arthur Koestler and a m...
# 534            Photograph of a young girl in a park ::
# 567                           Mural with four women ::
#
#                  expected_label    fold  \
# 128  ['Omission', 'Stereotype']  split4
# 382  ['Omission', 'Stereotype']  split4
# 466              ['Stereotype']  split4
# 534              ['Stereotype']  split4
# 567              ['Stereotype']  split4
#
#                                            pers_o_pred predicted_label  \
# 128  ['Unknown', 'Feminine', 'Occupation', 'Masculi...      Stereotype
# 382                                        ['Unknown']      Stereotype
# 466                                              ['O']      Stereotype
# 534                                              ['O']      Stereotype
# 567                                              ['O']      Stereotype
#
#         eadid
# 128       BAI
# 382       BAI
# 466  Coll-146
# 534  Coll-146
# 567  Coll-146

# %% [markdown]
# Save the data sample:

# %%
subdf.to_csv("../data/crc_metadata/stereotype_descs_from_top3_labeled_fonds.csv")

# %%
exp = 2

# %%
output_dir = "../data/token_clf_data/experiment{n}/5fold/output/".format(n=exp)
f = output_dir+"aggregated_final_predictions_docclf_sgd-svm_so.csv"                     # From 5-fold cross validation
df = pd.read_csv(f, index_col=0)
df.head()
# Out:
#     description_id  start_offset  end_offset                      field  \
# 6             3027           627        1162  Biographical / Historical
# 7             3397          8095        8334  Biographical / Historical
# 10            4736          9951       10026  Biographical / Historical
# 14            4712          4199        4485  Biographical / Historical
# 22           15684           845        1179  Biographical / Historical
#
#                                           description    manual_label    fold  \
# 6   Thomas Young was probably born in 1725. By the...  ['Stereotype']  split4
# 7   Andrew Tait worked on Paramecium in Beale's la...    ['Omission']  split4
# 10    Delivered by Thomson to teachers in Darlington.    ['Omission']  split4
# 14  This was gifted by Thomson to his secretary, M...    ['Omission']  split4
# 22  Catherine Robina Borland was responsible for t...            ['']  split4
#
#                              doc_ling_pred   sgd-svm_label      eadid
# 6   ['Generalization', 'Gendered-Pronoun']  ['Stereotype']  Coll-1253
# 7                     ['Gendered-Pronoun']    ['Omission']  Coll-1255
# 10                                    ['']    ['Omission']  Coll-1310
# 14                    ['Gendered-Pronoun']    ['Omission']  Coll-1310
# 22  ['Generalization', 'Gendered-Pronoun']            ['']  Coll-1453

# %%
top_om = pd.read_csv("../data/crc_metadata/top50_omission_desc_count.csv", index_col=0)
top_om = top_om.sort_values(by="omission_exp2_desc_count", ascending=False)
top_om_eadids = list(top_st.eadid)[:3]
df = df.loc[df.eadid.isin(top_om_eadids)]
# Only keep the rows with a label
df = utils.getColumnValuesAsLists(df, "sgd-svm_label")
df_exploded = df.explode(["sgd-svm_label"])
subdf = df_exploded.loc[df_exploded["sgd-svm_label"] == "Omission"]
print(subdf.shape)
subdf.head()
# Out:
# (1090, 10)
#      description_id  start_offset  end_offset                      field  \
# 128             720           136        3561  Biographical / Historical
# 487            9113           378         435                      Title
# 567           22001          1788        1820                      Title
# 795           19093          1349        1409                      Title
# 815           11913           745         798                      Title
#
#                                            description  \
# 128  John Baillie was born in 1886, the son of Rev ...
# 487  Cows of the Buckhold Herd, owned by Dr. H. Watney
# 567                           Mural with four women ::
# 795  Kolomea Juni 1941 - Februar 1943 :: [Weinleber...
# 815      How Mr. Rhodes Liked to Travel in the Country
#
#                    manual_label    fold  \
# 128  ['Omission', 'Stereotype']  split4
# 487                        ['']  split4
# 567              ['Stereotype']  split4
# 795                ['Omission']  split4
# 815                ['Omission']  split4
#
#                                          doc_ling_pred sgd-svm_label  \
# 128  ['Gendered-Role', 'Generalization', 'Gendered-...      Omission
# 487                                               ['']      Omission
# 567                                  ['Gendered-Role']      Omission
# 795                                  ['Gendered-Role']      Omission
# 815                                  ['Gendered-Role']      Omission
#
#          eadid
# 128        BAI
# 487  Coll-1434
# 567   Coll-146
# 795   Coll-146
# 815  Coll-1434

# %% [markdown]
# Save the data sample:

# %%
subdf.to_csv("../data/crc_metadata/omission_descs_from_top3_labeled_fonds.csv")

# %% [markdown]
# ### Analysis By Metadata Field

# %%
top_df = top_om
# Remove NaN
top_df = top_df.dropna()

# %%
cols = "unit_title", "unit_identifier", "unique_language", "unique_date", "unique_geography"
for col_name in cols:
    top_df = utils.getColumnValuesAsLists(top_df, col_name)
# Out:
# /afs/inf.ed.ac.uk/group/project/s1545703/gender-bias/analysis/utils.py:327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col_name] = col_list_values

# %%
titles = list(top_df.unit_title)
fonds_titles = [title_list[0] for title_list in titles]
print(fonds_titles)
# Out:
# ['Roslin Slide Collection', 'Papers of Godfrey H. Thomson', 'Papers of Professor Walter Ledermann', 'Papers of Richard Alan Beatty', 'Collection of Ian R. Grant', 'Papers of Alan W. Greenwood', 'Papers of Marjory Kennedy-Fraser', 'Papers of Sir John Jackson', 'Papers of Professor John Baillie', 'Material relating to Albert E. G. Pilliner', 'Patrick Geddes Collection', 'Letter from Mendelssohn-Bartholdy to J. Thomson', 'George Baillie Collection of Music Manuscripts', 'Letters of Frederick Sleigh Roberts', 'Papers and other material relating to C. Wyville Thomson', 'Letters of W. S. Morrison to his brother', 'Letter', 'Material relating to Helen Millar Lowe', 'Material relating to Tours of Duty with Colonial Medical Service', 'The staggering state of the Scottish statesmen', 'Material relating to Hugh Marwick', 'Letters of Ralph Erskine', 'Letter', 'Papers of Andrew Nisbet Bogle', 'Notes of lectures given by William Saunders', 'Papers of Lewis T. Waters', 'Research writings of Dr. Ewart Geoffrey Walsh', 'Letter from the University of Aberdeen to My Dear Sir', 'Papers of Dr. J. M. Caborn', 'Material relating to John W. L. Spence', 'Correspondence between Dr. Ian M. L. Hunter and Prof. Alexander C. Aitken', 'Papers relating to James Campbell', 'Letter to John Aitken', 'Letters from Dr. R.H.Thouless to Dr. D.J.Bruce', 'Corrected script of A season in hell by Arthur Rimbaud (1854-1891)', 'Class cards']

# %%
languages = list(top_df.unique_language)
# # Flatten the list
flat_languages = []
for language_list in languages:
    if type(language_list) == list:
        for lang in language_list:
            flat_languages += [lang]
unique_languages = list(set(flat_languages))
print(len(unique_languages))
print(unique_languages)
# Out:
# 24
# ['Spanish', 'English', 'Burmese', 'Hebrew', 'Dutch', 'Flemish', 'Czech', 'German', 'Scots Dialect', 'Scots dialect', 'French', 'English Gaelic', 'Gaelic Scottish Gaelic', 'Swedish', 'Latin', 'Irish Gaelic', 'Greek', 'Scottish Gaelic', 'Mostly English', 'Scots', 'Polish', 'Russian', 'Italian', 'Multiple languages']

# %%
geographies = list(top_df.unique_geography)
# # Flatten the list
flat_geographies = []
for geography_list in geographies:
    if type(geography_list) == list:
        for geography in geography_list:
            flat_geographies += [geography]
unique_geographies = list(set(flat_geographies))
print(len(unique_geographies))
print(unique_geographies)
# Out:
# 426
# ['', 'Lancashire (England)', 'Karlsburg (Germany)', 'Manitoba Canada', 'Ranchi (India)', 'Burma -- Mandalay', 'British Columbia (Canada)', 'United States)', 'Guyana', 'Canada', 'Zanzibar (Tanzania)', 'North', 'Mez&#337;hegyes (Hungary)', 'Dartmoor (England)', 'Delhi (India)', 'Rio de la Plata River Valley (Argentina and Uruguay)', 'United States -- Connecticut', 'England -- Salford', 'Cyrenaica (Libya)', 'West', 'Bervie (Scotland)', 'Saskatchewan (Canada)', 'Shropshire (England)', 'Buenos Aires (Argentina)', 'Oxfordshire England', 'Omsk (Russia)', 'Wye Mills Talbot County', 'Buckinghamshire England', 'Scotland -- Kinross', 'Bulawayo (Zimbabwe)', 'Mount (New Zealand)', 'Sudan', 'Scotland -- Orkney', 'Cirencester West Gloucestershire England', 'Northwest Territories (Canada)', 'Winnipeg (Manitoba', 'Uganda', 'Crieff (Scotland)', 'Woburn (England)', 'Hisar (India)', 'Woking (England)', 'Ireland', 'Leeds (England)', 'Aberdeen Scotland', 'California (United States)', 'Edinburgh (Scotland)', 'Corfu Island (Greece)', 'Norfolk (England)', 'Ufa (Russia)', 'Dinard France', 'Lahore District (Pakistan)', 'Scotland -- Perth', 'Colorado -- Denver', 'Chile', 'United States', 'Kent (England)', 'New York City (New York', 'Sumatra (Indonesia)', 'Nova Scotia (Canada)', 'Ghana', 'Vancouver (British Columbia', 'Syria', 'England', 'Lincolnshire (England)', 'Leicester (England)', 'Wigan Lancashire England', 'Hawick Roxburghshire Scotland', 'Simla (India)', 'Missouri (United States)', 'Great Britain', 'Athabasca River (Alberta', 'Oxford Oxfordshire England', 'Toronto (Ontario', 'Madagascar', 'Budapest (Hungary)', 'England -- Warwickshire -- Rugby', 'Belgium', 'West (United States)', 'Newmarket (Suffolk', 'Gairloch (parish) Ross and Cromarty Scotland', 'Scotland -- Inverness-shire -- Kingussie', 'Sydney (New South Wales', 'Kenya', 'Cupar (Scotland)', 'New Mexico (United States)', 'United Sates -- Wisconsin -- Milwaukee', 'Roorkee (India)', 'Hungary', 'Queensland (Australia)', 'Victoria Falls (Zimbabwe)', 'Devon England', 'United States -- Massachusetts', 'Yucatán (Mexico : State)', 'Zimbabwe Africa', 'Germany -- Lower Saxony -- Hanover', 'South Africa', 'Maryland United States of America', 'Uruguay', 'Cardiff (Wales)', 'Lake (Botswana)', 'Russia', 'Moy Inverness-shire Scotland', 'Punjab (Pakistan)', 'Gloucestershire (England)', 'Burma -- Rangoon', 'Malay Peninsula', 'Merseyside England', 'Essex (England)', 'Santa Cruz River Valley (Ariz. and Mexico)', 'Selkirk (Scotland)', 'Kasauli (India)', 'Islington (London', 'Tibet (China)', 'Wishaw (Scotland)', 'Suez', 'New Zealand', 'Sheffield (England)', 'Yorkshire (England)', 'Northern Ireland', 'New South Wales (Australia)', 'Pentland Hills (Scotland)', '1899-1902', 'Africa', 'Kilmacolm (Scotland)', 'South Dakota (United States)', 'Scotland -- East Lothian -- Longniddry', 'Cheshire (England)', 'Switzerland', 'Galloway (Scotland)', 'Jutland (Denmark)', 'Asia', 'Derbyshire (England)', 'Geelong (Victoria', 'Leamington (England)', 'Mesopotamia', 'Minnesota (United States)', 'Darjeeling (India)', 'Princeton New Jersey United States', 'Scottish Borders (Scotland)', 'Australia)', 'Scotland -- Edinburgh -- Dalmeny -- Queensferry', 'Pyrenees (France and Spain)', 'Edmonton (Alberta', 'Malaysia', 'China', 'United States of America -- North Carolina', 'Pennsylvania United States of America', 'St Andrews (Scotland)', 'Salisbury (England)', 'Hull (England)', 'New Hampshire (United States)', 'Collynie Aberdeenshire (Scotland)', 'Amman (Jordan)', 'Scotland -- Inverness-shire -- Mingulay -- Leapanan Chaluim Chille', 'Kensington (London', 'Scotland -- Argyllshire -- parish -- Glenorchy and Inishail -- Cladich', 'San Antonio (Texas', 'Sweden', 'Horsham (West Sussex', 'Richmond (England)', 'Staffordshire (England)', 'Central Africa', 'Orkney Scotland', 'Meath (Ireland)', 'United States of America', 'Poland', 'Waikato (New Zealand)', 'Exmoor (England)', 'Dumfriesshire (Scotland)', 'Berkshire (England)', 'St Louis (Missouri', 'Egy ...

# %%
top_df = top_st
# Remove NaN
top_df = top_df.dropna()

# %%
cols = "unit_title", "unit_identifier", "unique_language", "unique_date", "unique_geography"
for col_name in cols:
    top_df = utils.getColumnValuesAsLists(top_df, col_name)

# %%
titles = list(top_df.unit_title)
fonds_titles = [title_list[0] for title_list in titles]
print(fonds_titles)
# Out:
# ['Roslin Slide Collection', 'Papers of Professor John Baillie', 'Papers of Alan W. Greenwood', 'Roslin Institute Offprint Collection', 'Papers of Marjory Kennedy-Fraser', 'Susan Binnie Anderson', 'Papers and other material relating to C. Wyville Thomson', 'Papers and artwork of Yolanda Sonnabend relating to her collaboration with C.H. Waddington', 'Collection relating to Winifred Rushforth', 'Papers of Sir Thomas Hudson Middleton', 'Papers of Godfrey H. Thomson', 'Papers of Allan Maconochie (Lord Meadowbank) - Legal material', 'Papers of Dr. J. M. Caborn', 'Collection of Ian R. Grant', 'Material relating to the winding up of the Edinburgh Association for the University Education of Women', 'George Baillie Collection of Music Manuscripts', 'Journal of a tour round the world taken by Sir John Fraser (1885-1947)', 'Letter from the University of Aberdeen to My Dear Sir', 'Research writings of Dr. Ewart Geoffrey Walsh', 'Notes of lectures given by William Saunders', 'Correspondence between Dr. Ian M. L. Hunter and Prof. Alexander C. Aitken', 'Medals and Honours awarded to Sir George Taylor', 'William Logie', 'Material relating to John W. L. Spence', 'MS letter (autograph signed) by Violet Jacob', 'Photographs from drawings by W. Vandevelde Junr', 'Papers of Hamish Henderson', 'Papers of Professor Robert Bertram Serjeant', 'Lectures - New approach to Middle English dialectology / On planning a dialect survey of Scotland', 'Law notes of Professor Hector MacQueen', 'Papers of Rev. Bruce Kenrick', 'Letter from Sir David Brewster to the Editor', 'Papers of Andrew Nisbet Bogle', 'Papers of Sir John Jackson', 'Letter to John Aitken', 'Papers relating to James Campbell', 'Letters of W. S. Morrison to his brother', 'The staggering state of the Scottish statesmen', 'Letters of Ralph Erskine', 'Timothy L. S. Sprigge Archive']

# %%
languages = list(top_df.unique_language)
# # Flatten the list
flat_languages = []
for language_list in languages:
    if type(language_list) == list:
        for lang in language_list:
            flat_languages += [lang]
unique_languages = list(set(flat_languages))
print(len(unique_languages))
print(unique_languages)
# Out:
# 23
# ['Spanish', 'Arabic', 'English', 'Burmese', 'Hebrew', 'Czech', 'German', 'Scots Dialect', 'Scots dialect', 'French', 'English Gaelic', 'Gaelic Scottish Gaelic', 'Swedish', 'Latin', 'Irish Gaelic', 'Scottish Gaelic', 'Greek', 'Mostly English', 'Scots', 'Russian', 'Polish', 'Italian', 'Multiple languages']

# %%
geographies = list(top_df.unique_geography)
# # Flatten the list
flat_geographies = []
for geography_list in geographies:
    if type(geography_list) == list:
        for geography in geography_list:
            flat_geographies += [geography]
unique_geographies = list(set(flat_geographies))
print(len(unique_geographies))
print(unique_geographies)
# Out:
# 444
# ['', 'Lancashire (England)', 'Karlsburg (Germany)', 'Manitoba Canada', 'Ranchi (India)', 'Burma -- Mandalay', 'British Columbia (Canada)', 'United States)', 'Guyana', 'Canada', 'Zanzibar (Tanzania)', 'North', 'Mez&#337;hegyes (Hungary)', 'Dartmoor (England)', 'Delhi (India)', 'Rio de la Plata River Valley (Argentina and Uruguay)', 'United States -- Connecticut', 'England -- Salford', 'Cyrenaica (Libya)', 'West', 'Bervie (Scotland)', 'Saskatchewan (Canada)', 'Shropshire (England)', 'Buenos Aires (Argentina)', 'Oxfordshire England', 'Omsk (Russia)', 'Wye Mills Talbot County', 'Buckinghamshire England', 'Scotland -- Kinross', 'Bulawayo (Zimbabwe)', 'Arctic regions', 'Mount (New Zealand)', 'Sudan', 'Scotland -- Orkney', 'Cirencester West Gloucestershire England', 'Northwest Territories (Canada)', 'Winnipeg (Manitoba', 'Uganda', 'Crieff (Scotland)', 'Woburn (England)', 'Hisar (India)', 'Woking (England)', 'Ireland', 'Leeds (England)', 'Aberdeen Scotland', 'California (United States)', 'Edinburgh (Scotland)', 'Corfu Island (Greece)', 'Norfolk (England)', 'Ufa (Russia)', 'Dinard France', 'Lahore District (Pakistan)', 'Scotland -- Perth', 'Colorado -- Denver', 'Chile', 'United States', 'Kent (England)', 'New York City (New York', 'Sumatra (Indonesia)', 'Nova Scotia (Canada)', 'Ghana', 'Vancouver (British Columbia', 'Syria', 'England', 'Lincolnshire (England)', 'Yemen | Description and travel | | |', 'Leicester (England)', 'Wigan Lancashire England', 'Hawick Roxburghshire Scotland', 'Simla (India)', 'Missouri (United States)', 'Great Britain', 'Athabasca River (Alberta', 'Oxford Oxfordshire England', 'Toronto (Ontario', 'Madagascar', 'Budapest (Hungary)', 'England -- Warwickshire -- Rugby', 'Belgium', 'West (United States)', 'Newmarket (Suffolk', 'Gairloch (parish) Ross and Cromarty Scotland', 'Kirkwall (Scotland) |', 'Scotland -- Inverness-shire -- Kingussie', 'Sydney (New South Wales', 'Kenya', 'Cupar (Scotland)', 'New Mexico (United States)', 'United Sates -- Wisconsin -- Milwaukee', 'Roorkee (India)', 'Hungary', 'Ivory Coast', 'Queensland (Australia)', 'Victoria Falls (Zimbabwe)', 'Devon England', 'United States -- Massachusetts', 'Yucatán (Mexico : State)', 'Zimbabwe Africa', 'Germany -- Lower Saxony -- Hanover', 'South Africa', 'Maryland United States of America', 'Uruguay', 'Cardiff (Wales)', 'Lake (Botswana)', 'West Indies', 'Russia', 'Moy Inverness-shire Scotland', 'Cuba', 'Punjab (Pakistan)', 'Gloucestershire (England)', 'Burma -- Rangoon', 'Malay Peninsula', 'Merseyside England', 'Essex (England)', 'Santa Cruz River Valley (Ariz. and Mexico)', 'Selkirk (Scotland)', 'Kasauli (India)', 'Islington (London', 'Tibet (China)', 'Wishaw (Scotland)', 'Suez', 'New Zealand', 'Sheffield (England)', 'Yorkshire (England)', 'Northern Ireland', 'New South Wales (Australia)', 'Pentland Hills (Scotland)', '1899-1902', 'Africa', 'Kilmacolm (Scotland)', 'South Dakota (United States)', 'Scotland -- East Lothian -- Longniddry', 'Cheshire (England)', 'Switzerland', 'Galloway (Scotland)', 'Jutland (Denmark)', 'Asia', 'Derbyshire (England)', 'Geelong (Victoria', 'Leamington (England)', 'Mesopotamia', 'Minnesota (United States)', 'Darjeeling (India)', 'Southern', 'Princeton New Jersey United States', 'Scottish Borders (Scotland)', 'Australia)', 'Scotland -- Edinburgh -- Dalmeny -- Queensferry', 'Pyrenees (France and Spain)', 'Edmonton (Alberta', 'Malaysia', 'China', 'United States of America -- North Carolina', 'Pennsylvania United States of America', 'St Andrews (Scotland)', 'Salisbury (England)', 'Hull (England)', 'New Hampshire (United States)', 'Collynie Aberdeenshire (Scotland)', 'Amman (Jordan)', 'Scotland -- Inverness-shire -- Mingulay -- Leapanan Chaluim Chille', 'Kensington (London', 'Scotland -- Argyllshire -- parish -- Glenorchy and Inishail -- Cladich', 'San Antonio (Texas', 'Sweden', 'Horsham (West Sussex', 'Richmond (England)', 'Staffordshire (England)', 'Central Africa', 'Orkney Scotland', 'Meath (Ireland)', 'United States of America', ...

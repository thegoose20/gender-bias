# %% [markdown]
# # Analysis: Token BIO Tags
#
# ## Post Annotation and Aggregation
#
# Determine which description each annotated text span occurs in and then determine which tokens are in an annotated text span.
#
# ***
#
# **Table of Contents**
#
# [0](#0). Load libraries
#
# [1](#1). Load and Transform Data
#
# [2](#2). Associate Annotations to a Description
#
# [3](#3). Assign BIO Tags
#
# ***
#
# ### 0. Load libraries:

# %%
import utils  # import custom functions
import config # import directory path variables

from pathlib import Path

import pandas as pd
import numpy as np
import string, csv, re, os, sys #,json

import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
# nltk.download('punkt')
from nltk.corpus import PlaintextCorpusReader
# nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.tag import pos_tag
from nltk.text import Text
from nltk.probability import FreqDist
from collections import Counter

# %matplotlib inline
import matplotlib.pyplot as plt

from intervaltree import Interval, IntervalTree

# %% [markdown]
# ### 1. Load and Transform Data
#
# **Load description and annotation data and transform the datasets to more easily associate description IDs to annotation IDs.**

# %%
df_tokens = pd.read_csv(config.tokc_path+"descid_token_offsets.csv")
df_tokens = df_tokens.drop(columns=["Unnamed: 0"])
token_desc_ids = list(df_tokens.desc_id)
tokens = list(df_tokens.token)
token_offsets = list(df_tokens.offsets)
token_offsets_clean = [offsets[1:-1].split(", ") for offsets in token_offsets]
token_offsets_tuples = [tuple((int(offsets[0]), int(offsets[1]))) for offsets in token_offsets_clean]
token_offsets_tuples[:5]  # Looks good
# Out:
# [(29, 36), (37, 39), (40, 43), (44, 57), (58, 65)]

# %% [markdown]
# Associate description tokens and annotated text spans' text and offsets to description IDs.

# %%
df_tokens_imploded = utils.implodeDataFrame(df_tokens, ["desc_id"])
df_tokens_imploded = df_tokens_imploded.rename(columns={"offsets":"token_offsets"})
df_tokens_imploded.head()
# Out:
#                                                      token  \
# desc_id
# 0        [Records, of, the, Phrenological, Society, of,...
# 1        [The, records, of, the, Phrenological, Society...
# 2        [The, Phrenological, Society, of, Edinburgh, w...
# 3        [Letter, :, 1825, Jan., 10, ,, 27, Lower, Belg...
# 4        [Letter, :, 1825, Mar, ., 1, ,, 27, Lower, Bel...
#
#                                              token_offsets
# desc_id
# 0        [(29, 36), (37, 39), (40, 43), (44, 57), (58, ...
# 1        [(100, 103), (104, 111), (112, 114), (115, 118...
# 2        [(638, 641), (642, 655), (656, 663), (664, 666...
# 3        [(7, 13), (13, 14), (15, 19), (20, 24), (25, 2...
# 4        [(125, 131), (131, 132), (133, 137), (138, 141...

# %%
df_tokens_imploded.to_csv(config.tokc_path+"token_data_imploded.csv")

# %% [markdown]
# Load the data associating description and annotation IDs to offsets.

# %%
df_descs = pd.read_csv(config.crc_meta_path+"descs_with_offsets.csv", index_col=0)

# Remove file extensions
desc_filenames = list(df_descs.file)
desc_filenames = [f[:-4] for f in desc_filenames]
df_descs.insert(1, "filename", desc_filenames)

# Make sure offsets are in one column as tuples of ints
start_offsets = list(df_descs.desc_start_offset)
end_offsets = list(df_descs.desc_end_offset)
offsets_strs = list(zip(list(df_descs.desc_start_offset),list(df_descs.desc_end_offset)))
offsets_int_tuples = utils.turnStrTuplesToIntTuples(offsets_strs)
df_descs = df_descs.drop(columns=["desc_start_offset", "desc_end_offset"])
df_descs.insert(3, "desc_offsets", offsets_int_tuples)

df_descs.head()
# Out:
#    desc_id        filename     eadid desc_offsets                      field  \
# 0        0  Coll-227_00100  Coll-227     (29, 79)                      Title
# 1        1  Coll-227_00100  Coll-227   (100, 610)         Scope and Contents
# 2        2  Coll-227_00100  Coll-227  (638, 2277)  Biographical / Historical
# 3        3        La_03600        La     (7, 117)                      Title
# 4        4        La_03600        La   (125, 223)                      Title
#
#                  file                                        description
# 0  Coll-227_00100.txt  Records of the Phrenological Society of Edinburgh
# 1  Coll-227_00100.txt  The records of the Phrenological Society inclu...
# 2  Coll-227_00100.txt  The Phrenological Society of Edinburgh was for...
# 3        La_03600.txt  Letter: 1825 Jan. 10, 27 Lower Belgrave Place ...
# 4        La_03600.txt  Letter: 1825 Mar. 1, 27 Lower Belgrave Place [...

# %%
df_descs_imploded = utils.implodeDataFrame(df_descs, ["filename"])
df_descs_imploded.head()
# Out:
#                                                      desc_id  \
# filename
# AA4_00100                              [19714, 19715, 19716]
# AA5_00100                              [39870, 39871, 39872]
# AA6_00100                              [65922, 65923, 65924]
# AA7_00100                              [86719, 86720, 86721]
# BAI_00100  [278, 279, 280, 281, 282, 283, 284, 285, 286, ...
#
#                                                        eadid  \
# filename
# AA4_00100                                    [AA4, AA4, AA4]
# AA5_00100                                    [AA5, AA5, AA5]
# AA6_00100                                    [AA6, AA6, AA6]
# AA7_00100                                    [AA7, AA7, AA7]
# BAI_00100  [BAI, BAI, BAI, BAI, BAI, BAI, BAI, BAI, BAI, ...
#
#                                                 desc_offsets  \
# filename
# AA4_00100                  [(24, 69), (90, 505), (533, 985)]
# AA5_00100                 [(24, 76), (97, 633), (661, 1350)]
# AA6_00100                 [(24, 60), (81, 523), (588, 1031)]
# AA7_00100                  [(24, 76), (97, 417), (445, 934)]
# BAI_00100  [(24, 84), (92, 115), (123, 143), (151, 210), ...
#
#                                                        field  \
# filename
# AA4_00100  [Title, Scope and Contents, Biographical / His...
# AA5_00100  [Title, Scope and Contents, Biographical / His...
# AA6_00100  [Title, Scope and Contents, Biographical / His...
# AA7_00100  [Title, Scope and Contents, Biographical / His...
# BAI_00100  [Title, Title, Title, Title, Title, Title, Tit...
#
#                                                         file  \
# filename
# AA4_00100      [AA4_00100.txt, AA4_00100.txt, AA4_00100.txt]
# AA5_00100      [AA5_00100.txt, AA5_00100.txt, AA5_00100.txt]
# AA6_00100      [AA6_00100.txt, AA6_00100.txt, AA6_00100.txt]
# AA7_00100      [AA7_00100.txt, AA7_00100.txt, AA7_00100.txt]
# BAI_00100  [BAI_00100.txt, BAI_00100.txt, BAI_00100.txt, ...
#
#                                                  description
# filename
# AA4_00100  [Papers of Rev Prof John McIntyre (1916-2005),...
# AA5_00100  [Papers of The Very Rev Prof James Whyte (1920...
# AA6_00100  [Papers of Rev Tom Allan (1916-1965), Sermons ...
# AA7_00100  [Papers of Rev Prof Alec Campbell Cheyne (1924...
# BAI_00100  [Papers of Professor John Baillie, and Baillie...

# %%
descs_dict = (df_descs_imploded[["desc_id", "desc_offsets"]]).to_dict(orient="index")
# print(descs_dict) # Looks good

# %%
df_anns = pd.read_csv(config.agg_path+"aggregated_final.csv", index_col=0)

# Remove file extensions
desc_filenames = list(df_anns.file)
desc_filenames = [f[:-4] for f in desc_filenames]
df_anns.insert(1, "filename", desc_filenames)

# Make sure offsets are in one column as tuples of ints
offsets_strs = list(df_anns.offsets)
offsets_int_tuples = utils.turnStrTuplesToIntTuples(offsets_strs)
df_anns = df_anns.drop(columns=["offsets"])
df_anns.insert(3, "ann_offsets", offsets_int_tuples)

df_anns.head()
# Out:
#     agg_ann_id         filename                 file    ann_offsets  \
# 12           0  Coll-1157_00100  Coll-1157_00100.ann   (1407, 1415)
# 22           1  Coll-1310_02300  Coll-1310_02300.ann   (9625, 9635)
# 23           2  Coll-1281_00100  Coll-1281_00100.ann   (2426, 2439)
# 24           3  Coll-1310_02700  Coll-1310_02700.ann  (9993, 10003)
# 25           4  Coll-1310_02900  Coll-1310_02900.ann   (7192, 7195)
#
#              text          label    category associated_genders
# 12       knighted  Gendered-Role  Linguistic            Unclear
# 22     knighthood  Gendered-Role  Linguistic            Unclear
# 23  Prince Regent  Gendered-Role  Linguistic            Unclear
# 24     knighthood  Gendered-Role  Linguistic            Unclear
# 25            Sir  Gendered-Role  Linguistic            Unclear

# %%
df_anns_imploded = utils.implodeDataFrame(df_anns, ["filename"])
df_anns_imploded.head()
# Out:
#                                                   agg_ann_id  \
# filename
# AA5_00100  [14377, 14378, 14379, 14380, 14381, 14382, 143...
# AA6_00100  [55, 9516, 9517, 9518, 9519, 9520, 9521, 9522,...
# AA7_00100  [127, 13987, 13988, 13989, 13990, 13991, 13992...
# BAI_00100  [17473, 17474, 17475, 17476, 17477, 17478, 416...
# BAI_00200  [20496, 20497, 20498, 20499, 20500, 20501, 205...
#
#                                                         file  \
# filename
# AA5_00100  [AA5_00100.ann, AA5_00100.ann, AA5_00100.ann, ...
# AA6_00100  [AA6_00100.ann, AA6_00100.ann, AA6_00100.ann, ...
# AA7_00100  [AA7_00100.ann, AA7_00100.ann, AA7_00100.ann, ...
# BAI_00100  [BAI_00100.ann, BAI_00100.ann, BAI_00100.ann, ...
# BAI_00200  [BAI_00200.ann, BAI_00200.ann, BAI_00200.ann, ...
#
#                                                  ann_offsets  \
# filename
# AA5_00100  [(789, 791), (871, 873), (913, 916), (928, 930...
# AA6_00100  [(1778, 1790), (677, 679), (920, 922), (1222, ...
# AA7_00100  [(2399, 2415), (505, 508), (614, 620), (647, 6...
# BAI_00100  [(371, 388), (393, 405), (34, 56), (102, 114),...
# BAI_00200  [(215, 221), (226, 232), (250, 255), (285, 299...
#
#                                                         text  \
# filename
# AA5_00100  [He, he, his, he, he, His, he, The Very Rev Pr...
# AA6_00100  [Billy Graham, He, he, he, he, He, his, his, h...
# AA7_00100  [Professor Cheyne, son, sister, brother, His, ...
# BAI_00100  [Jacques Chevalier, Lloyd Morgan, Professor Jo...
# BAI_00200  [Barker, Garvie, Busch, Adolf Jülicher, Johann...
#
#                                                        label  \
# filename
# AA5_00100  [Gendered-Pronoun, Gendered-Pronoun, Gendered-...
# AA6_00100  [Masculine, Gendered-Pronoun, Gendered-Pronoun...
# AA7_00100  [Masculine, Gendered-Role, Gendered-Role, Gend...
# BAI_00100  [Unknown, Unknown, Unknown, Unknown, Unknown, ...
# BAI_00200  [Unknown, Unknown, Unknown, Unknown, Unknown, ...
#
#                                                     category  \
# filename
# AA5_00100  [Linguistic, Linguistic, Linguistic, Linguisti...
# AA6_00100  [Person-Name, Linguistic, Linguistic, Linguist...
# AA7_00100  [Person-Name, Linguistic, Linguistic, Linguist...
# BAI_00100  [Person-Name, Person-Name, Person-Name, Person...
# BAI_00200  [Person-Name, Person-Name, Person-Name, Person...
#
#                                           associated_genders
# filename
# AA5_00100  [Masculine, Masculine, Masculine, Masculine, M...
# AA6_00100  [Unclear, Masculine, Masculine, Masculine, Mas...
# AA7_00100  [Masculine, Unclear, Unclear, Multiple, Mascul...
# BAI_00100  [Masculine, Unclear, Unclear, Unclear, Unclear...
# BAI_00200  [Unclear, Unclear, Unclear, Multiple, Multiple...

# %%
anns_dict = (df_anns_imploded[["agg_ann_id", "ann_offsets"]]).to_dict(orient="index")
# print(anns_dict) # Looks good

# %% [markdown]
# ### 2. Associate Annotations to a Description
#
# **Using offsets, determine which annotation ID to match to which description ID.**

# %%
annid_to_descid = dict() #.fromkeys((list(df_anns.agg_ann_id)))
files = list(anns_dict.keys())
for f in files:
    # Get the IDs and offsets of annotations in that file
    f_ann_ids = anns_dict[f]["agg_ann_id"]
    f_ann_offsets = anns_dict[f]["ann_offsets"]
    
    # Get the IDs and offsets of descriptions in that file
    f_desc_ids = descs_dict[f]["desc_id"]
    f_desc_offsets = descs_dict[f]["desc_offsets"]
    
    # For every annotation, find the description it appears within
    for i in range(len(f_ann_ids)):
        start_ann_offset, end_ann_offset = f_ann_offsets[i][0], f_ann_offsets[i][1]
        for j in range(len(f_desc_ids)):
            start_desc_offset, end_desc_offset = f_desc_offsets[j][0], f_desc_offsets[j][1]
            if start_ann_offset >= start_desc_offset and start_ann_offset <= end_desc_offset:
                if end_ann_offset >= start_desc_offset and end_ann_offset <= end_desc_offset:
                    ann_id, desc_id = f_ann_ids[i], f_desc_ids[j]
                    annid_to_descid[ann_id] = desc_id

# %%
ann_to_desc_df = pd.DataFrame({"agg_ann_id":list(annid_to_descid.keys()), "desc_id":list(annid_to_descid.values())})
ann_to_desc_df.head()
# Out:
#    agg_ann_id  desc_id
# 0       14377    39872
# 1       14378    39872
# 2       14379    39872
# 3       14380    39872
# 4       14381    39872

# %%
df_anns = df_anns.set_index("agg_ann_id")
df_anns_with_desc = df_anns.join(ann_to_desc_df.set_index("agg_ann_id"), on="agg_ann_id", how="outer")
df_anns_with_desc.head()
# Out:
#                    filename                 file    ann_offsets  \
# agg_ann_id
# 0           Coll-1157_00100  Coll-1157_00100.ann   (1407, 1415)
# 1           Coll-1310_02300  Coll-1310_02300.ann   (9625, 9635)
# 2           Coll-1281_00100  Coll-1281_00100.ann   (2426, 2439)
# 3           Coll-1310_02700  Coll-1310_02700.ann  (9993, 10003)
# 4           Coll-1310_02900  Coll-1310_02900.ann   (7192, 7195)
#
#                      text          label    category associated_genders  \
# agg_ann_id
# 0                knighted  Gendered-Role  Linguistic            Unclear
# 1              knighthood  Gendered-Role  Linguistic            Unclear
# 2           Prince Regent  Gendered-Role  Linguistic            Unclear
# 3              knighthood  Gendered-Role  Linguistic            Unclear
# 4                     Sir  Gendered-Role  Linguistic            Unclear
#
#             desc_id
# agg_ann_id
# 0           49896.0
# 1           54748.0
# 2           71394.0
# 3           58054.0
# 4           25014.0

# %%
df_anns_with_desc.loc[df_anns_with_desc.desc_id.isnull()]
# Out:
#                    filename                 file       ann_offsets  \
# agg_ann_id
# 11          Coll-1036_00400  Coll-1036_00400.ann    (86191, 86196)
# 13          Coll-1036_00400  Coll-1036_00400.ann    (37968, 37973)
# 19          Coll-1036_00400  Coll-1036_00400.ann  (104833, 104840)
# 20          Coll-1036_00400  Coll-1036_00400.ann    (45180, 45187)
# 21          Coll-1036_00400  Coll-1036_00400.ann    (49859, 49878)
# ...                     ...                  ...               ...
# 55235       Coll-1234_00100  Coll-1234_00100.ann      (1260, 1264)
# 55236       Coll-1234_00100  Coll-1234_00100.ann      (1350, 1356)
# 55237       Coll-1234_00100  Coll-1234_00100.ann      (1384, 1387)
# 55252       Coll-1434_18400  Coll-1434_18400.ann          (64, 67)
# 55259       Coll-1439_00100  Coll-1439_00100.ann      (2333, 2337)
#
#                            text           label     category  \
# agg_ann_id
# 11                        Women   Gendered-Role   Linguistic
# 13                        Woman   Gendered-Role   Linguistic
# 19                      McNeill         Unknown  Person-Name
# 20                      Kennedy         Unknown  Person-Name
# 21          Hood, Helen Patuffa         Unknown  Person-Name
# ...                         ...             ...          ...
# 55235                      wife  Generalization   Linguistic
# 55236                    father  Generalization   Linguistic
# 55237                       Mrs  Generalization   Linguistic
# 55252                       men  Generalization   Linguistic
# 55259                      Miss  Generalization   Linguistic
#
#            associated_genders  desc_id
# agg_ann_id
# 11                   Feminine      NaN
# 13                   Feminine      NaN
# 19                    Unclear      NaN
# 20                    Unclear      NaN
# 21                  Masculine      NaN
# ...                       ...      ...
# 55235                Feminine      NaN
# 55236                Multiple      NaN
# 55237                 Unclear      NaN
# 55252               Masculine      NaN
# 55259                 Unclear      NaN
#
# [7224 rows x 8 columns]

# %% [markdown]
# WHY DO THE ANNOTATIONS IN THE DF ABOVE NOT HAVE A CORRESPONDING DESCRIPTION???

# %%
df_descs.loc[df_descs["filename"] == "Coll-1036_00400"]
# Out:
#        desc_id         filename      eadid    desc_offsets  \
# 68307    68307  Coll-1036_00400  Coll-1036     (137, 1264)
# 68308    68308  Coll-1036_00400  Coll-1036    (1285, 1361)
# 68309    68309  Coll-1036_00400  Coll-1036    (1584, 1837)
# 68310    68310  Coll-1036_00400  Coll-1036    (1858, 2033)
# 68311    68311  Coll-1036_00400  Coll-1036    (2054, 5254)
# 68312    68312  Coll-1036_00400  Coll-1036    (5275, 5552)
# 68313    68313  Coll-1036_00400  Coll-1036    (5573, 5941)
# 68314    68314  Coll-1036_00400  Coll-1036    (6004, 6022)
# 68315    68315  Coll-1036_00400  Coll-1036    (6842, 6902)
# 68316    68316  Coll-1036_00400  Coll-1036    (6923, 6939)
# 68317    68317  Coll-1036_00400  Coll-1036   (7331, 12028)
# 68318    68318  Coll-1036_00400  Coll-1036  (12049, 12165)
# 68319    68319  Coll-1036_00400  Coll-1036  (12186, 12388)
# 68320    68320  Coll-1036_00400  Coll-1036  (12409, 13035)
# 68321    68321  Coll-1036_00400  Coll-1036  (13056, 29974)
#
#                     field                 file  \
# 68307  Scope and Contents  Coll-1036_00400.txt
# 68308  Scope and Contents  Coll-1036_00400.txt
# 68309  Scope and Contents  Coll-1036_00400.txt
# 68310  Scope and Contents  Coll-1036_00400.txt
# 68311  Scope and Contents  Coll-1036_00400.txt
# 68312  Scope and Contents  Coll-1036_00400.txt
# 68313  Scope and Contents  Coll-1036_00400.txt
# 68314  Scope and Contents  Coll-1036_00400.txt
# 68315  Scope and Contents  Coll-1036_00400.txt
# 68316  Scope and Contents  Coll-1036_00400.txt
# 68317  Scope and Contents  Coll-1036_00400.txt
# 68318  Scope and Contents  Coll-1036_00400.txt
# 68319  Scope and Contents  Coll-1036_00400.txt
# 68320  Scope and Contents  Coll-1036_00400.txt
# 68321  Scope and Contents  Coll-1036_00400.txt
#
#                                              description
# 68307  Miscellaneous music.Several Marjory Kennedy-Fr...
# 68308  Miscellaneous items, Part 1, 2,  3.'Burns as a...
# 68309  'Loose Leaf M.S.S. [manuscripts] of "Book"'. S...
# 68310  'News Cuttings', note book. Softbound, charcoa...
# 68311  Various music collections, Part 1  2. Part 1: ...
# 68312  'Proofs  M.S.S.[manuscripts], More Songs of [t...
# 68313  'Kennedy-Fraser MSS. [manuscripts], D. 18377 [...
# 68314                                  'Tolmie  Gesto'.
# 68315  Proofs of A Life of Song by Marjory Kennedy-Fr...
# 68316                                    Breton songs.
# 68317  Miscellaneous working material, Part 1, 2, 3, ...
# 68318  Les 15 Modes de la Musique Bretonne, by Mauric...
# 68319  'Printed music collections.Scots Songs: Marjor...
# 68320  Printed music collections.Recueil de chants po...
# 68321  Miscellaneous proofs of Songs of the Hebrides,...

# %% [markdown]
# LOOKS LIKE DESCRIPTION OFFSETS NEED TO BE REGENERAGTED BECAUSE SOME DESCRIPTIONS ARE MISSING FROM THE DF_DESCS DATAFRAME (descs_with_offsets.csv)!

# %% [markdown]
# ### 3. Assign BIO Tags
#
# **Compare the descriptions' tokens' offsets to the annotated text spans' offsets to determine which tokens to mark as the beginning of an annotation (`B-[LABELNAME]`), inside an annotation (`I-[LABELNAME]`), and unannotated, or outisde of an annotation (`O`).**

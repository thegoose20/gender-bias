# %% [markdown]
# # Review Aggregation of Annotated Data
#
# * Check for file mismatches
# * Check description IDs - should be based on every description from every file uploaded to brat rapid annotation tool, rather than only on descriptions that have annotations in them!

# %%
import pandas as pd
import numpy as np

# %%
doc_clf_df = pd.read_csv("../doc_clf_data/desc_field_descid_label_eadid_exploded.csv")
doc_clf_df = doc_clf_df.drop(columns=["Unnamed: 0"])
print(doc_clf_df.shape)
doc_clf_df.head()
# Out:
# (1605, 8)
#        eadid                 file  desc_id                      field  \
# 0  Coll-1320  Coll-1320_00400.txt     3247                      Title
# 1  Coll-1320  Coll-1320_00400.txt     3247                      Title
# 2   Coll-146   Coll-146_28000.txt    11317         Scope and Contents
# 3   Coll-146   Coll-146_20500.txt     9233         Scope and Contents
# 4  Coll-1130  Coll-1130_00100.txt     1465  Biographical / Historical
#
#                                          description      label  \
# 0  'Effect of an inhibitor of 3ß-hydroxysteroid d...  Masculine
# 1  'Effect of an inhibitor of 3ß-hydroxysteroid d...    Unknown
# 2  3 photographs : negative, col.Sent from: [Cap ...    Unknown
# 3  4 photographs : negative, col.. 1 stripSent fr...    Unknown
# 4  A collection of copied letters, mainly from th...    Unknown
#
#    desc_start_offset  desc_end_offset
# 0               5040             5281
# 1               5040             5281
# 2               4731             4810
# 3               4387             4592
# 4               1262             1434

# %%
final_df = pd.read_csv("aggregated_final.csv", index_col=0)
final_df.head()
# Out:
#     agg_ann_id                 file        offsets           text  \
# 12           0  Coll-1157_00100.ann   (1407, 1415)       knighted
# 22           1  Coll-1310_02300.ann   (9625, 9635)     knighthood
# 23           2  Coll-1281_00100.ann   (2426, 2439)  Prince Regent
# 24           3  Coll-1310_02700.ann  (9993, 10003)     knighthood
# 25           4  Coll-1310_02900.ann   (7192, 7195)            Sir
#
#             label    category associated_genders
# 12  Gendered-Role  Linguistic            Unclear
# 22  Gendered-Role  Linguistic            Unclear
# 23  Gendered-Role  Linguistic            Unclear
# 24  Gendered-Role  Linguistic            Unclear
# 25  Gendered-Role  Linguistic            Unclear

# %% [markdown]
# Check for duplicate annotations:

# %%
final_subdf = final_df.drop_duplicates()
assert final_subdf.shape[0] == final_df.shape[0], "Every row of annotation data should be unique"

# %% [markdown]
# Great!  There are no duplicates in the final aggregated data, `aggregated_final.csv`.
#
# ***

# %% [markdown]
# Next review the description data files:

# %%
desc_to_review = ["../doc_clf_data/desc_field_descid_label_eadid.csv", "../data/analysis_data/descriptions_with_counts.csv"]

# %%
df = pd.read_csv(desc_to_review[0])
df.drop(columns=["Unnamed: 0"], inplace=True)
df.head()
# Out:
#        eadid                 file  desc_id                      field  \
# 0  Coll-1320  Coll-1320_00400.txt     3247                      Title
# 1   Coll-146   Coll-146_28000.txt    11317         Scope and Contents
# 2   Coll-146   Coll-146_20500.txt     9233         Scope and Contents
# 3  Coll-1130  Coll-1130_00100.txt     1465  Biographical / Historical
# 4  Coll-1143  Coll-1143_00100.txt     1493  Biographical / Historical
#
#                                          description  \
# 0  'Effect of an inhibitor of 3ß-hydroxysteroid d...
# 1  3 photographs : negative, col.Sent from: [Cap ...
# 2  4 photographs : negative, col.. 1 stripSent fr...
# 3  A collection of copied letters, mainly from th...
# 4  Alexander Herbert Main studied Law at Edinburg...
#
#                                                label  desc_start_offset  \
# 0                           {'Masculine', 'Unknown'}             5040.0
# 1                                        {'Unknown'}             4731.0
# 2                                        {'Unknown'}             4387.0
# 3                                        {'Unknown'}             1262.0
# 4  {'Gendered-Pronoun', 'Stereotype', 'Masculine'...             1170.0
#
#    desc_end_offset
# 0           5281.0
# 1           4810.0
# 2           4592.0
# 3           1434.0
# 4           1559.0

# %%
annot_descids = list(df.desc_id)
annot_descs = list(df.description)
annot_descs = [desc.strip() for desc in annot_descs]
df["description"] = annot_descs
annot_descs_ids = dict(zip(annot_descids,annot_descs))

# %%
# descs = pd.read_csv("../crc_metadata/all_descriptions.csv", index_col=0)
# print(descs.shape)
# descs.head()

# %%
all_descids = list(descs.desc_id)
all_descs = list(descs.description)
all_descs = [desc.strip() for desc in all_descs]
descs["description"] = all_descs
all_descs_ids = dict(zip(all_descids,all_descs))

# %%
only_annot = [desc for desc in annot_descs if not desc in all_descs]
print(len(only_annot))
# Out:
# 0

# %%
only_annotids = [did for did in annot_descs_ids if not did in all_descs_ids]
print(len(only_annotids))
# Out:
# 0

# %% [markdown]
# There seems to be a mismatch between the description IDs. - NOW FIXED

# %%
subdf = df.loc[df.desc_id.isin(only_annotids)]
assert subdf.shape[0] == len(only_annotids)
subdf.head()
# Out:
#                                          description  \
# 0                           John Baillie: posthumous
# 1  Letters received from Henry Sloane Coffin, wit...
# 2  Family photographs consist of:photographs of f...
# 3  Correspondence and related items, including le...
# 4  From 1927-1930 John Baillie was Professor of S...
#
#                        field  \
# 0                      Title
# 1         Scope and Contents
# 2         Scope and Contents
# 3         Scope and Contents
# 4  Biographical / Historical
#
#                                                label eadid  desc_id  \
# 0                                        {'Unknown'}   BAI    70381
# 1                           {'Masculine', 'Unknown'}   BAI    47675
# 2               {'Masculine', 'Unknown', 'Feminine'}   BAI    81505
# 3                                        {'Unknown'}   BAI    33009
# 4  {'Gendered-Pronoun', 'Unknown', 'Masculine', '...   BAI    43372
#
#             file  desc_start_offset  desc_end_offset
# 0  BAI_01000.txt               1290             1315
# 1  BAI_01300.txt               5853             5983
# 2  BAI_01600.txt               5967             6202
# 3  BAI_01900.txt               5297             5506
# 4  BAI_02200.txt              15180            15419

# %% [markdown]
# Compare `subdf`'s `description`, `field`, and `file` columns to `descs` to see whether or not they're all present in `descs`:

# %%
subdf = subdf.set_index(["description","field","eadid"])
subdf.head()
# Out:
#                                                                                                                                 label  \
# description                                        field                     eadid
# John Baillie: posthumous                           Title                     BAI                                          {'Unknown'}
# Letters received from Henry Sloane Coffin, with... Scope and Contents        BAI                             {'Masculine', 'Unknown'}
# Family photographs consist of:photographs of fa... Scope and Contents        BAI                 {'Masculine', 'Unknown', 'Feminine'}
# Correspondence and related items, including let... Scope and Contents        BAI                                          {'Unknown'}
# From 1927-1930 John Baillie was Professor of Sy... Biographical / Historical BAI    {'Gendered-Pronoun', 'Unknown', 'Masculine', '...
#
#                                                                                     desc_id  \
# description                                        field                     eadid
# John Baillie: posthumous                           Title                     BAI      70381
# Letters received from Henry Sloane Coffin, with... Scope and Contents        BAI      47675
# Family photographs consist of:photographs of fa... Scope and Contents        BAI      81505
# Correspondence and related items, including let... Scope and Contents        BAI      33009
# From 1927-1930 John Baillie was Professor of Sy... Biographical / Historical BAI      43372
#
#                                                                                              file  \
# description                                        field                     eadid
# John Baillie: posthumous                           Title                     BAI    BAI_01000.txt
# Letters received from Henry Sloane Coffin, with... Scope and Contents        BAI    BAI_01300.txt
# Family photographs consist of:photographs of fa... Scope and Contents        BAI    BAI_01600.txt
# Correspondence and related items, including let... Scope and Contents        BAI    BAI_01900.txt
# From 1927-1930 John Baillie was Professor of Sy... Biographical / Historical BAI    BAI_02200.txt
#
#                                                                                     desc_start_offset  \
# description                                        field                     eadid
# John Baillie: posthumous                           Title                     BAI                 1290
# Letters received from Henry Sloane Coffin, with... Scope and Contents        BAI                 5853
# Family photographs consist of:photographs of fa... Scope and Contents        BAI                 5967
# Correspondence and related items, including let... Scope and Contents        BAI                 5297
# From 1927-1930 John Baillie was Professor of Sy... Biographical / Historical BAI                15180
#
#                                                                                     desc_end_offset
# description                                        field                     eadid
# John Baillie: posthumous                           Title                     BAI               1315
# Letters received from Henry Sloane Coffin, with... Scope and Contents        BAI               5983
# Family photographs consist of:photographs of fa... Scope and Contents        BAI               6202
# Correspondence and related items, including let... Scope and Contents        BAI               5506
# From 1927-1930 John Baillie was Professor of Sy... Biographical / Historical BAI              15419

# %%
joined = subdf.join(descs.set_index(["description", "field", "eadid"]), how="outer", lsuffix="subdf", rsuffix="descs")
joined.head()
# Out:
#                                                                    label  \
# description                                        field eadid
#                                                    Title Coll-1310   NaN
# "All That Was Left of Them": The Thirteen Sole ... Title Coll-1434   NaN
# "Baron o' Buchlyvie" (11410)                       Title Coll-1434   NaN
# "Baron's Pride"                                    Title Coll-1434   NaN
# "Duke of Northumberland" (1940)                    Title Coll-1434   NaN
#
#                                                                     desc_idsubdf  \
# description                                        field eadid
#                                                    Title Coll-1310           NaN
# "All That Was Left of Them": The Thirteen Sole ... Title Coll-1434           NaN
# "Baron o' Buchlyvie" (11410)                       Title Coll-1434           NaN
# "Baron's Pride"                                    Title Coll-1434           NaN
# "Duke of Northumberland" (1940)                    Title Coll-1434           NaN
#
#                                                                    file  \
# description                                        field eadid
#                                                    Title Coll-1310  NaN
# "All That Was Left of Them": The Thirteen Sole ... Title Coll-1434  NaN
# "Baron o' Buchlyvie" (11410)                       Title Coll-1434  NaN
# "Baron's Pride"                                    Title Coll-1434  NaN
# "Duke of Northumberland" (1940)                    Title Coll-1434  NaN
#
#                                                                     desc_start_offset  \
# description                                        field eadid
#                                                    Title Coll-1310                NaN
# "All That Was Left of Them": The Thirteen Sole ... Title Coll-1434                NaN
# "Baron o' Buchlyvie" (11410)                       Title Coll-1434                NaN
# "Baron's Pride"                                    Title Coll-1434                NaN
# "Duke of Northumberland" (1940)                    Title Coll-1434                NaN
#
#                                                                     desc_end_offset  \
# description                                        field eadid
#                                                    Title Coll-1310              NaN
# "All That Was Left of Them": The Thirteen Sole ... Title Coll-1434              NaN
# "Baron o' Buchlyvie" (11410)                       Title Coll-1434              NaN
# "Baron's Pride"                                    Title Coll-1434              NaN
# "Duke of Northumberland" (1940)                    Title Coll-1434              NaN
#
#                                                                     desc_iddescs
# description                                        field eadid
#                                                    Title Coll-1310         11892
# "All That Was Left of Them": The Thirteen Sole ... Title Coll-1434          4733
# "Baron o' Buchlyvie" (11410)                       Title Coll-1434          4311
# "Baron's Pride"                                    Title Coll-1434          4569
# "Duke of Northumberland" (1940)                    Title Coll-1434          4603

# %%
joined.shape
# Out:
# (15887, 6)

# %%
joined_notnull = joined.loc[~joined.desc_idsubdf.isnull()]
print(joined_notnull.shape)
joined_null = joined.loc[joined.desc_idsubdf.isnull()]
print(joined_null.shape)
# Out:
# (4300, 6)
# (11587, 6)

# %%
joined_notnull.head()
# Out:
#                                                                                                                                     label  \
# description                                        field                     eadid
# 'Effect of an inhibitor of 3ß-hydroxysteroid de... Title                     Coll-1320                           {'Masculine', 'Unknown'}
# 3 photographs : negative, col.Sent from: [Cap F... Scope and Contents        Coll-146                                         {'Unknown'}
# 4 photographs : negative, col.. 1 stripSent fro... Scope and Contents        Coll-146                                         {'Unknown'}
# A collection of copied letters, mainly from the... Biographical / Historical Coll-1130                                        {'Unknown'}
# Alexander Herbert Main studied Law at Edinburgh... Biographical / Historical Coll-1143  {'Gendered-Pronoun', 'Stereotype', 'Masculine'...
#
#                                                                                         desc_idsubdf  \
# description                                        field                     eadid
# 'Effect of an inhibitor of 3ß-hydroxysteroid de... Title                     Coll-1320       19370.0
# 3 photographs : negative, col.Sent from: [Cap F... Scope and Contents        Coll-146        63842.0
# 4 photographs : negative, col.. 1 stripSent fro... Scope and Contents        Coll-146        66091.0
# A collection of copied letters, mainly from the... Biographical / Historical Coll-1130       20367.0
# Alexander Herbert Main studied Law at Edinburgh... Biographical / Historical Coll-1143       48400.0
#
#                                                                                                        file  \
# description                                        field                     eadid
# 'Effect of an inhibitor of 3ß-hydroxysteroid de... Title                     Coll-1320  Coll-1320_00400.txt
# 3 photographs : negative, col.Sent from: [Cap F... Scope and Contents        Coll-146    Coll-146_28000.txt
# 4 photographs : negative, col.. 1 stripSent fro... Scope and Contents        Coll-146    Coll-146_20500.txt
# A collection of copied letters, mainly from the... Biographical / Historical Coll-1130  Coll-1130_00100.txt
# Alexander Herbert Main studied Law at Edinburgh... Biographical / Historical Coll-1143  Coll-1143_00100.txt
#
#                                                                                         desc_start_offset  \
# description                                        field                     eadid
# 'Effect of an inhibitor of 3ß-hydroxysteroid de... Title                     Coll-1320             5040.0
# 3 photographs : negative, col.Sent from: [Cap F... Scope and Contents        Coll-146              4731.0
# 4 photographs : negative, col.. 1 stripSent fro... Scope and Contents        Coll-146              4387.0
# A collection of copied letters, mainly from the... Biographical / Historical Coll-1130             1262.0
# Alexander Herbert Main studied Law at Edinburgh... Biographical / Historical Coll-1143             1170.0
#
#                                                                                         desc_end_offset  \
# description                                        field                     eadid
# 'Effect of an inhibitor of 3ß-hydroxysteroid de... Title                     Coll-1320           5281.0
# 3 photographs : negative, col.Sent from: [Cap F... Scope and Contents        Coll-146            4810.0
# 4 photographs : negative, col.. 1 stripSent fro... Scope and Contents        Coll-146            4592.0
# A collection of copied letters, mainly from the... Biographical / Historical Coll-1130           1434.0
# Alexander Herbert Main studied Law at Edinburgh... Biographical / Historical Coll-1143           1559.0
#
#                                                                                         desc_iddescs
# description                                        field                     eadid
# 'Effect of an inhibitor of 3ß-hydroxysteroid de... Title                     Coll-1320          3247
# 3 photographs : negative, col.Sent from: [Cap F... Scope and Contents        Coll-146          11317
# 4 photographs : negative, col.. 1 stripSent fro... Scope and Contents        Coll-146           9233
# A collection of copied letters, mainly from the... Biographical / Historical Coll-1130          1465
# Alexander Herbert Main studied Law at Edinburgh... Biographical / Historical Coll-1143          1493

# %%
joined_notnull.isnull().values.any()  # False so no nulls in any column - great!
# Out:
# False

# %% [markdown]
# Now we want to keep the `desc_id` column from the `descs` DataFrame, since that contains the complete list of descriptions (all those in all files uploaded to the brat rapid annotation tool).

# %%
joined_notnull = joined_notnull.drop(columns=["desc_idsubdf"])
joined_notnull = joined_notnull.rename({"desc_iddescs":"desc_id"}, axis=1)
joined_notnull = joined_notnull.reset_index()
joined_notnull.head()
# Out:
#                                          description  \
# 0  'Effect of an inhibitor of 3ß-hydroxysteroid d...
# 1  3 photographs : negative, col.Sent from: [Cap ...
# 2  4 photographs : negative, col.. 1 stripSent fr...
# 3  A collection of copied letters, mainly from th...
# 4  Alexander Herbert Main studied Law at Edinburg...
#
#                        field      eadid  \
# 0                      Title  Coll-1320
# 1         Scope and Contents   Coll-146
# 2         Scope and Contents   Coll-146
# 3  Biographical / Historical  Coll-1130
# 4  Biographical / Historical  Coll-1143
#
#                                                label                 file  \
# 0                           {'Masculine', 'Unknown'}  Coll-1320_00400.txt
# 1                                        {'Unknown'}   Coll-146_28000.txt
# 2                                        {'Unknown'}   Coll-146_20500.txt
# 3                                        {'Unknown'}  Coll-1130_00100.txt
# 4  {'Gendered-Pronoun', 'Stereotype', 'Masculine'...  Coll-1143_00100.txt
#
#    desc_start_offset  desc_end_offset  desc_id
# 0             5040.0           5281.0     3247
# 1             4731.0           4810.0    11317
# 2             4387.0           4592.0     9233
# 3             1262.0           1434.0     1465
# 4             1170.0           1559.0     1493

# %% [markdown]
# Add on the remainder of the `df` rows (those that did have description IDs that were in the `descs` DataFrame):

# %%
subdf2 = df.loc[~df.desc_id.isin(only_annotids)]
print(subdf2.shape)
# Out:
# (205, 8)

# %%
subdf2 = subdf2.set_index(["description","field","eadid","desc_id"])
subdf2.head()
# Out:
#                                                                                                                                             label  \
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172                             {'Occupation', 'Unknown'}
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697                 {'Occupation', 'Omission', 'Unknown'}
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122                               {'Omission', 'Unknown'}
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566                     {'Gendered-Pronoun', 'Masculine'}
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493     {'Masculine', 'Occupation', 'Gendered-Pronoun'...
#
#                                                                                                                file  \
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172           BAI_02500.txt
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697     Coll-1057_00700.txt
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122     Coll-1064_00100.txt
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566     Coll-1069_00100.txt
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493     Coll-1070_00100.txt
#
#                                                                                                 desc_start_offset  \
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172                  1224
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697                 11621
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122                  1259
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566                   207
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493                   461
#
#                                                                                                 desc_end_offset
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172                1277
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697               12142
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122                1289
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566                 279
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493                 975

# %%
joined2 = subdf2.join(descs.set_index(["description", "field", "eadid", "desc_id"]), how="left", lsuffix="subdf2", rsuffix="descs")
assert joined2.shape[0] == subdf2.shape[0]
joined2.head()
# Out:
#                                                                                                                                             label  \
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172                             {'Occupation', 'Unknown'}
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697                 {'Occupation', 'Omission', 'Unknown'}
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122                               {'Omission', 'Unknown'}
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566                     {'Gendered-Pronoun', 'Masculine'}
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493     {'Masculine', 'Occupation', 'Gendered-Pronoun'...
#
#                                                                                                                file  \
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172           BAI_02500.txt
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697     Coll-1057_00700.txt
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122     Coll-1064_00100.txt
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566     Coll-1069_00100.txt
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493     Coll-1070_00100.txt
#
#                                                                                                 desc_start_offset  \
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172                  1224
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697                 11621
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122                  1259
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566                   207
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493                   461
#
#                                                                                                 desc_end_offset
# description                                        field                     eadid     desc_id
# Archivist's NoteNone  Grant Buttars 25 February... Processing Information    BAI       4172                1277
# Contains:Poultry Research Centre reports and as... Scope and Contents        Coll-1057 6697               12142
# 33 (37), Thomson to Ledermann                      Title                     Coll-1064 7122                1289
# Robert Forester wrote the title page to his boo... Biographical / Historical Coll-1069 1566                 279
# The photographs were the work of publisher and ... Biographical / Historical Coll-1070 6493                 975

# %%
joined2.isnull().values.any()  # Great!
# Out:
# False

# %%
joined2 = joined2.reset_index()
joined2.head()
# Out:
#                                          description  \
# 0  Archivist's NoteNone  Grant Buttars 25 Februar...
# 1  Contains:Poultry Research Centre reports and a...
# 2                      33 (37), Thomson to Ledermann
# 3  Robert Forester wrote the title page to his bo...
# 4  The photographs were the work of publisher and...
#
#                        field      eadid  desc_id  \
# 0     Processing Information        BAI     4172
# 1         Scope and Contents  Coll-1057     6697
# 2                      Title  Coll-1064     7122
# 3  Biographical / Historical  Coll-1069     1566
# 4  Biographical / Historical  Coll-1070     6493
#
#                                                label                 file  \
# 0                          {'Occupation', 'Unknown'}        BAI_02500.txt
# 1              {'Occupation', 'Omission', 'Unknown'}  Coll-1057_00700.txt
# 2                            {'Omission', 'Unknown'}  Coll-1064_00100.txt
# 3                  {'Gendered-Pronoun', 'Masculine'}  Coll-1069_00100.txt
# 4  {'Masculine', 'Occupation', 'Gendered-Pronoun'...  Coll-1070_00100.txt
#
#    desc_start_offset  desc_end_offset
# 0               1224             1277
# 1              11621            12142
# 2               1259             1289
# 3                207              279
# 4                461              975

# %%
new_df = pd.concat([joined_notnull,joined2], axis=0, ignore_index=True, sort=True)
assert new_df.isnull().values.any() == False

# %%
# Reorder the columns
new_df = new_df[["eadid","file","desc_id","field","description","label","desc_start_offset","desc_end_offset"]]
new_df.head()
# Out:
#        eadid                 file  desc_id                      field  \
# 0  Coll-1320  Coll-1320_00400.txt     3247                      Title
# 1   Coll-146   Coll-146_28000.txt    11317         Scope and Contents
# 2   Coll-146   Coll-146_20500.txt     9233         Scope and Contents
# 3  Coll-1130  Coll-1130_00100.txt     1465  Biographical / Historical
# 4  Coll-1143  Coll-1143_00100.txt     1493  Biographical / Historical
#
#                                          description  \
# 0  'Effect of an inhibitor of 3ß-hydroxysteroid d...
# 1  3 photographs : negative, col.Sent from: [Cap ...
# 2  4 photographs : negative, col.. 1 stripSent fr...
# 3  A collection of copied letters, mainly from th...
# 4  Alexander Herbert Main studied Law at Edinburg...
#
#                                                label  desc_start_offset  \
# 0                           {'Masculine', 'Unknown'}             5040.0
# 1                                        {'Unknown'}             4731.0
# 2                                        {'Unknown'}             4387.0
# 3                                        {'Unknown'}             1262.0
# 4  {'Gendered-Pronoun', 'Stereotype', 'Masculine'...             1170.0
#
#    desc_end_offset
# 0           5281.0
# 1           4810.0
# 2           4592.0
# 3           1434.0
# 4           1559.0

# %%
new_df = new_df.drop_duplicates()
new_df.shape
# Out:
# (983, 8)

# %%
df.shape
# Out:
# (1855, 8)

# %%
df.head()
# Out:
#                                          description  \
# 0                           John Baillie: posthumous
# 1  Letters received from Henry Sloane Coffin, wit...
# 2  Family photographs consist of:photographs of f...
# 3  Correspondence and related items, including le...
# 4  From 1927-1930 John Baillie was Professor of S...
#
#                        field  \
# 0                      Title
# 1         Scope and Contents
# 2         Scope and Contents
# 3         Scope and Contents
# 4  Biographical / Historical
#
#                                                label eadid  desc_id  \
# 0                                        {'Unknown'}   BAI    70381
# 1                           {'Masculine', 'Unknown'}   BAI    47675
# 2               {'Masculine', 'Unknown', 'Feminine'}   BAI    81505
# 3                                        {'Unknown'}   BAI    33009
# 4  {'Gendered-Pronoun', 'Unknown', 'Masculine', '...   BAI    43372
#
#             file  desc_start_offset  desc_end_offset
# 0  BAI_01000.txt               1290             1315
# 1  BAI_01300.txt               5853             5983
# 2  BAI_01600.txt               5967             6202
# 3  BAI_01900.txt               5297             5506
# 4  BAI_02200.txt              15180            15419

# %%
descs_df = list(df.description)
fields_df = list(df.field)
files_df = list(df.file)
i, maxI = 0, len(descs_df)
subrows_df = [files_df[i]+" "+fields_df[i]+" "+descs_df[i] for i in range(maxI)]
print(subrows_df[0])
# Out:
# BAI_01000.txt Title John Baillie: posthumous

# %%
descs_newdf = list(new_df.description)
fields_newdf = list(new_df.field)
files_newdf = list(new_df.file)
i, maxI = 0, len(descs_newdf)
subrows_newdf = [files_newdf[i]+" "+fields_newdf[i]+" "+descs_newdf[i] for i in range(maxI)]
print(subrows_newdf[0])
# Out:
# Coll-1320_00400.txt Title 'Effect of an inhibitor of 3ß-hydroxysteroid dehydrogenase on progesterone concentrations and embryo survival in sheep', C.J. Ashworth, I. Wilmut, A.J. Springbett and R. Webb, reprinted from the Journal of Endocrinology (1987), 112, 205-213

# %%
missing_from_new = [s for s in subrows_df if not s in subrows_newdf]
print(len(missing_from_new))
# Out:
# 0

# %% [markdown]
# In certain cases, it seems, the same description had accidentally been assigned more than one identifier (`desc_id`), making it seem as though there were more unique descriptions than there actually were.  I'll rename the old data file just in case I'd like it for reference and then write a new data file under the old file's previous name:

# %%
# new_df.to_csv(desc_to_review[0])  # file: desc_to_review = "../doc_clf_data/desc_field_descid_label_eadid.csv"
new_df = pd.read_csv(desc_to_review[0], index_col=0)

# %% [markdown]
# Make sure the other description data file's IDs align with those in `new_df`:

# %%
df = pd.read_csv(desc_to_review[1])  # file: "../token_clf_data/descid_token_offsets.csv"
df_descids = list(set(list(df.desc_id)))
print(len(df_descids))
# Out:
# 88597

# %%
new_df_descids = list(set(list(df.desc_id)))
print(len(new_df_descids))
# Out:
# 88597

# %%
df_descids.sort()
new_df_descids.sort()
assert df_descids == new_df_descids

# %% [markdown]
# Looks good!

# %% [markdown]
# ### Descriptions Data

# %%
descs_with_offsets = pd.read_csv("../crc_metadata/descs_with_offsets.csv", index_col=0)
descs_with_offsets.head()
# Out:
#    desc_id     eadid                      field                file  \
# 0        0  Coll-227                      Title  Coll-227_00100.txt
# 1        1  Coll-227         Scope and Contents  Coll-227_00100.txt
# 2        2  Coll-227  Biographical / Historical  Coll-227_00100.txt
# 3        3        La                      Title        La_03600.txt
# 4        4        La                      Title        La_03600.txt
#
#                                          description  desc_start_offset  \
# 0  Records of the Phrenological Society of Edinburgh                 29
# 1  The records of the Phrenological Society inclu...                100
# 2  The Phrenological Society of Edinburgh was for...                638
# 3  Letter: 1825 Jan. 10, 27 Lower Belgrave Place ...                  7
# 4  Letter: 1825 Mar. 1, 27 Lower Belgrave Place [...                125
#
#    desc_end_offset
# 0               79
# 1              610
# 2             2277
# 3              117
# 4              223

# %%
descs_with_offsets.shape
# Out:
# (88597, 7)

# %%
descs_with_offsets_dedup = descs_with_offsets.drop_duplicates()
descs_with_offsets_dedup.shape
# Out:
# (88597, 7)

# %%
descs = descs_with_offsets.drop(columns=["file", "desc_start_offset", "desc_end_offset"])
descs = descs.drop_duplicates()
descs.shape
# Out:
# (88597, 4)

# %% [markdown]
# No duplicate rows!

# %%
print(len(set(list(descs_with_offsets.desc_id))))
# Out:
# 88597

# %% [markdown]
# No duplicate IDs!

# %%
len(set(list(descs_with_offsets.file)))
# Out:
# 3645

# %%
descs_with_offsets.loc[descs_with_offsets.file == "Coll-1036_00400.txt"]
# Out:
#        desc_id      eadid               field                 file  \
# 68307    68307  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68308    68308  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68309    68309  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68310    68310  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68311    68311  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68312    68312  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68313    68313  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68314    68314  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68315    68315  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68316    68316  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68317    68317  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68318    68318  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68319    68319  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68320    68320  Coll-1036  Scope and Contents  Coll-1036_00400.txt
# 68321    68321  Coll-1036  Scope and Contents  Coll-1036_00400.txt
#
#                                              description  desc_start_offset  \
# 68307  Miscellaneous music.Several Marjory Kennedy-Fr...                137
# 68308  Miscellaneous items, Part 1, 2,  3.'Burns as a...               1285
# 68309  'Loose Leaf M.S.S. [manuscripts] of "Book"'. S...               1584
# 68310  'News Cuttings', note book. Softbound, charcoa...               1858
# 68311  Various music collections, Part 1  2. Part 1: ...               2054
# 68312  'Proofs  M.S.S.[manuscripts], More Songs of [t...               5275
# 68313  'Kennedy-Fraser MSS. [manuscripts], D. 18377 [...               5573
# 68314                                  'Tolmie  Gesto'.                6004
# 68315  Proofs of A Life of Song by Marjory Kennedy-Fr...               6842
# 68316                                    Breton songs.                 6923
# 68317  Miscellaneous working material, Part 1, 2, 3, ...               7331
# 68318  Les 15 Modes de la Musique Bretonne, by Mauric...              12049
# 68319  'Printed music collections.Scots Songs: Marjor...              12186
# 68320  Printed music collections.Recueil de chants po...              12409
# 68321  Miscellaneous proofs of Songs of the Hebrides,...              13056
#
#        desc_end_offset
# 68307             1264
# 68308             1361
# 68309             1837
# 68310             2033
# 68311             5254
# 68312             5552
# 68313             5941
# 68314             6022
# 68315             6902
# 68316             6939
# 68317            12028
# 68318            12165
# 68319            12388
# 68320            13035
# 68321            29974

# %% [markdown]
# All present...why annotations among them not found when trying to assign desc IDs to annotations in TokenBIOTags notebook???

# %%
descs_with_offsets.loc[descs_with_offsets.file == "Coll-1234_00100.txt"]
# Out:
#        desc_id      eadid                      field                 file  \
# 80165    80165  Coll-1234                      Title  Coll-1234_00100.txt
# 80166    80166  Coll-1234         Scope and Contents  Coll-1234_00100.txt
# 80167    80167  Coll-1234  Biographical / Historical  Coll-1234_00100.txt
# 80168    80168  Coll-1234     Processing Information  Coll-1234_00100.txt
#
#                                              description  desc_start_offset  \
# 80165   Papers relating to James Campbell, of Carsphairn                 30
# 80166             The collection of papers includes:                    100
# 80167  James Campbell was born at Carsphairn (Dumfrie...               1507
# 80168  Compiled by Graeme D. Eddie, Edinburgh Univers...               2688
#
#        desc_end_offset
# 80165               79
# 80166              139
# 80167             2663
# 80168             2767

# %% [markdown]
# Something missing here...there's too big a gab between the description start and end offsets.

# %%
descs_with_offsets.loc[descs_with_offsets.desc_id == 80166].description
# Out:
# 80166    The collection of papers includes:
# Name: description, dtype: object
